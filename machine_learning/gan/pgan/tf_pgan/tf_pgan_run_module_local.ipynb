# %% [markdown]
# # Run model module locally

# %%
import os

# Import os environment variables for file hyperparameters.
os.environ["TRAIN_FILE_PATTERN"] = "gs://machine-learning-1234-bucket/gan/pgan/data/train*.tfrecord"
os.environ["EVAL_FILE_PATTERN"] = "gs://machine-learning-1234-bucket/gan/pgan/data/test*.tfrecord"
os.environ["OUTPUT_DIR"] = "gs://machine-learning-1234-bucket/gan/pgan/trained_model"

# Import os environment variables for train hyperparameters.
os.environ["TRAIN_BATCH_SIZE"] = str(32)
os.environ["TRAIN_STEPS"] = str(20)

# Import os environment variables for eval hyperparameters.
os.environ["EVAL_BATCH_SIZE"] = str(32)
os.environ["EVAL_STEPS"] = str(10)
os.environ["START_DELAY_SECS"] = str(60)
os.environ["THROTTLE_SECS"] = str(120)

# Import os environment variables for image hyperparameters.
os.environ["HEIGHT"] = str(32)
os.environ["WIDTH"] = str(32)
os.environ["DEPTH"] = str(3)

# Import os environment variables for shared hyperparameters.
os.environ["BASE_NUM_FILTERS"] = "512,512"
os.environ["BASE_KERNEL_SIZES"] = "4,3"
os.environ["BASE_STRIDES"] = "1,1"

os.environ["NUM_STEPS_UNTIL_GROWTH"] = str(100)

os.environ["GROWTH_NUM_FILTERS"] = "512,512;512,512"
os.environ["GROWTH_KERNEL_SIZES"] = "3,3;3,3"
os.environ["GROWTH_STRIDES"] = "1,1;1,1"

# Import os environment variables for generator hyperparameters.
os.environ["LATENT_SIZE"] = str(512)
os.environ["GENERATOR_PROJECTION_DIMS"] = "4,4,512"
os.environ["GENERATOR_L1_REGULARIZATION_SCALE"] = str(0.01)
os.environ["GENERATOR_L2_REGULARIZATION_SCALE"] = str(0.01)
os.environ["GENERATOR_OPTIMIZER"] = "Adam"
os.environ["GENERATOR_LEARNING_RATE"] = str(0.0001)
os.environ["GENERATOR_CLIP_GRADIENTS"] = str(5.0)
os.environ["GENERATOR_TRAIN_STEPS"] = str(1)

# Import os environment variables for discriminator hyperparameters.
os.environ["DISCRIMINATOR_L1_REGULARIZATION_SCALE"] = str(0.01)
os.environ["DISCRIMINATOR_L2_REGULARIZATION_SCALE"] = str(0.01)
os.environ["DISCRIMINATOR_OPTIMIZER"] = "Adam"
os.environ["DISCRIMINATOR_LEARNING_RATE"] = str(0.0001)
os.environ["DISCRIMINATOR_CLIP_GRADIENTS"] = str(5.0)
os.environ["DISCRIMINATOR_GRADIENT_PENALTY_COEFFICIENT"] = str(10.0)
os.environ["DISCRIMINATOR_TRAIN_STEPS"] = str(5)

# %% [markdown]
# ## Train WGAN-GP model

# %%
# %%bash
# rm -rf trained_model
# export PYTHONPATH=$PYTHONPATH:$PWD/pgan_module
# python3 -m trainer.task \
#     --train_file_pattern=${TRAIN_FILE_PATTERN} \
#     --eval_file_pattern=${EVAL_FILE_PATTERN} \
#     --output_dir=${OUTPUT_DIR} \
#     --job-dir=./tmp \
#     \
#     --train_batch_size=${TRAIN_BATCH_SIZE} \
#     --train_steps=${TRAIN_STEPS} \
#     \
#     --eval_batch_size=${EVAL_BATCH_SIZE} \
#     --eval_steps=${EVAL_STEPS} \
#     --start_delay_secs=${START_DELAY_SECS} \
#     --throttle_secs=${THROTTLE_SECS} \
#     \
#     --height=${HEIGHT} \
#     --width=${WIDTH} \
#     --depth=${DEPTH} \
#     \
#     --base_num_filters=${BASE_NUM_FILTERS} \
#     --base_kernel_sizes=${BASE_KERNEL_SIZES} \
#     --base_strides=${BASE_STRIDES} \
#     --num_steps_until_growth=${NUM_STEPS_UNTIL_GROWTH} \
#     --growth_num_filters=${GROWTH_NUM_FILTERS} \
#     --growth_kernel_sizes=${GROWTH_KERNEL_SIZES} \
#     --growth_strides=${GROWTH_STRIDES} \
#     \
#     --latent_size=${LATENT_SIZE} \
#     --generator_projection_dims=${GENERATOR_PROJECTION_DIMS} \
#     --generator_l1_regularization_scale=${GENERATOR_L1_REGULARIZATION_SCALE} \
#     --generator_l2_regularization_scale=${GENERATOR_L2_REGULARIZATION_SCALE} \
#     --generator_optimizer=${GENERATOR_OPTIMIZER} \
#     --generator_learning_rate=${GENERATOR_LEARNING_RATE} \
#     --generator_clip_gradients=${GENERATOR_CLIP_GRADIENTS} \
#     --generator_train_steps=${GENERATOR_TRAIN_STEPS} \
#     \
#     --discriminator_l1_regularization_scale=${DISCRIMINATOR_L1_REGULARIZATION_SCALE} \
#     --discriminator_l2_regularization_scale=${DISCRIMINATOR_L2_REGULARIZATION_SCALE} \
#     --discriminator_optimizer=${DISCRIMINATOR_OPTIMIZER} \
#     --discriminator_learning_rate=${DISCRIMINATOR_LEARNING_RATE} \
#     --discriminator_clip_gradients=${DISCRIMINATOR_CLIP_GRADIENTS} \
#     --discriminator_gradient_penalty_coefficient=${DISCRIMINATOR_GRADIENT_PENALTY_COEFFICIENT} \
#     --discriminator_train_steps=${DISCRIMINATOR_TRAIN_STEPS}
# Out:
# decode_example: features = {'image_raw': FixedLenFeature(shape=[], dtype=tf.string, default_value=None), 'label': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None)}
# decode_example: image = Tensor("DecodeRaw:0", shape=(?,), dtype=uint8)
# decode_example: image = Tensor("Reshape:0", shape=(32, 32, 3), dtype=uint8)
# decode_example: image = Tensor("sub:0", shape=(32, 32, 3), dtype=float32)
# decode_example: label = Tensor("Cast_1:0", shape=(), dtype=int32)
#
# pgan_model: features = {'image': <tf.Tensor 'IteratorGetNext:0' shape=(?, 32, 32, 3) dtype=float32>}
# pgan_model: labels = Tensor("IteratorGetNext:1", shape=(?,), dtype=int32, device=/device:CPU:0)
# pgan_model: mode = train
# pgan_model: params = {'train_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/train*.tfrecord', 'eval_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/test*.tfrecord', 'output_dir': 'gs://machine-learning-1234-bucket/gan/pgan/trained_model/', 'train_batch_size': 32, 'train_steps': 20, 'eval_batch_size': 32, 'eval_steps': 10, 'start_delay_secs': 60, 'throttle_secs': 120, 'height': 32, 'width': 32, 'depth': 3, 'base_num_filters': [512, 512], 'base_kernel_sizes': [4, 3], 'base_strides': [1, 1], 'num_steps_until_growth': 100, 'growth_num_filters': [[512, 512], [512, 512]], 'growth_kernel_sizes': [[3, 3], [3, 3]], 'growth_strides': [[1, 1], [1, 1]], 'latent_size': 512, 'generator_projection_dims': [4, 4, 512], 'generator_l1_regularization_scale': 0.01, 'generator_l2_regularization_scale': 0.01, 'generator_optimizer': 'Adam', 'generator_learning_rate': 0.0001, 'generator_clip_gradients': 5.0, 'generator_train_steps': 1, 'discriminator_l1_regularization_scale': 0.01, 'discriminator_l2_regularization_scale': 0.01, 'discriminator_optimizer': 'Adam', 'discriminator_learning_rate': 0.0001, 'discriminator_clip_gradients': 5.0, 'discriminator_gradient_penalty_coefficient': 10.0, 'discriminator_train_steps': 5}
# pgan_model: alpha_var = <tf.Variable 'alpha_var:0' shape=() dtype=float32_ref>
#
# Call generator with Z = Tensor("random_normal:0", shape=(?, 512), dtype=float32).
#
# generator_network: Z = Tensor("random_normal:0", shape=(?, 512), dtype=float32)
# generator_network: projection = Tensor("generator/projection_layer/LeakyRelu:0", shape=(?, 8192), dtype=float32)
# generator_network: base_network = Tensor("generator/projection_reshaped:0", shape=(?, 4, 4, 512), dtype=float32)
#
# create_generator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684ad90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684ad50>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756926b90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756926e90>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756934d50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830290>]
# generator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684ad90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684ad50>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756926b90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756926e90>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756934d50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830290>]]
#
# create_generator_to_rgb_layers: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75686e7d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830d90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830dd0>]
# generator_network: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75686e7d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830d90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756830dd0>]
#
# create_base_generator_network: to_rgb_conv = Tensor("generator/base_to_rgb_layers_conv2d/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_0:0", shape=(?, ?, ?, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator_1/growth_upsampled_image_2/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_1:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_final_generator_network: to_rgb_conv = Tensor("generator/growth_to_rgb_layers_conv2d_1/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
# generator_network: generated_outputs = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# resize_real_images: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
#
# resize_real_image: block_idx = 0
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_0/ResizeNearestNeighbor:0", shape=(?, 4, 4, 3), dtype=float32)
#
# resize_real_image: block_idx = 1
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_1/ResizeNearestNeighbor:0", shape=(?, 8, 8, 3), dtype=float32)
#
# resize_real_image: block_idx = 2
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_2/ResizeNearestNeighbor:0", shape=(?, 16, 16, 3), dtype=float32)
# resize_real_images: selected resized_image = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# Call discriminator with real_image = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32).
#
# discriminator_network: X = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_discriminator_from_rgb_layers: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe757870f90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684add0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a610>]
# discriminator_network: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe757870f90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684add0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a610>]
#
# create_discriminator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a690>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756929910>]
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756899e90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684f910>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a13d0>
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568a1510>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568a1690>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a1850>
# discriminator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a690>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756929910>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756899e90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684f910>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a13d0>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568a1510>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568a1690>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a1850>]]
#
# create_discriminator_growth_transition_downsample_layers: downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe757870d50>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a19d0>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a1b10>]
# discriminator_network: transition_downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe757870d50>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a19d0>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7568a1b10>]
#
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 4, 4, 512), dtype=float32)
# create_base_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 8192), dtype=float32)
# create_base_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_base/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 8, 8, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 32768), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_0/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_1/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_final_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_final_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_final/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Call discriminator with generator_outputs = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32).
#
# discriminator_network: X = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_discriminator_from_rgb_layers: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684abd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a210>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568b3350>]
# discriminator_network: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684abd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75684a210>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568b3350>]
#
# create_discriminator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756929b50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7567596d0>]
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568aff10>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568aff50>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567dad50>
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7567c0f90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75677af10>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567a9890>
# discriminator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe756929b50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7567596d0>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568aff10>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7568aff50>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567dad50>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7567c0f90>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe75677af10>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567a9890>]]
#
# create_discriminator_growth_transition_downsample_layers: downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe75684a110>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe75684f710>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567eda90>]
# discriminator_network: transition_downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe75684a110>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe75684f710>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7567eda90>]
#
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 4, 4, 512), dtype=float32)
# create_base_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 8192), dtype=float32)
# create_base_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_base/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 8, 8, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 32768), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_0/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_1/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_final_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_final_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_final/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# get_generator_loss: generator_loss = Tensor("Neg:0", shape=(), dtype=float32)
# get_generator_loss: generator_regularization_loss = 0
# get_generator_loss: generator_total_loss = Tensor("generator_total_loss:0", shape=(), dtype=float32)
#
# get_discriminator_loss: discriminator_real_loss = Tensor("discriminator_2/discriminator_real_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_generated_loss = Tensor("discriminator_2/discriminator_generated_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_loss = Tensor("discriminator_2/discriminator_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_regularization_loss = 0
# get_discriminator_loss: discriminator_total_loss = Tensor("discriminator_2/discriminator_total_loss:0", shape=(), dtype=float32)
#
# decode_example: features = {'image_raw': FixedLenFeature(shape=[], dtype=tf.string, default_value=None), 'label': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None)}
# decode_example: image = Tensor("DecodeRaw:0", shape=(?,), dtype=uint8)
# decode_example: image = Tensor("Reshape:0", shape=(32, 32, 3), dtype=uint8)
# decode_example: image = Tensor("sub:0", shape=(32, 32, 3), dtype=float32)
# decode_example: label = Tensor("Cast_1:0", shape=(), dtype=int32)
#
# pgan_model: features = {'image': <tf.Tensor 'IteratorGetNext:0' shape=(?, 32, 32, 3) dtype=float32>}
# pgan_model: labels = Tensor("IteratorGetNext:1", shape=(?,), dtype=int32, device=/device:CPU:0)
# pgan_model: mode = eval
# pgan_model: params = {'train_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/train*.tfrecord', 'eval_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/test*.tfrecord', 'output_dir': 'gs://machine-learning-1234-bucket/gan/pgan/trained_model/', 'train_batch_size': 32, 'train_steps': 20, 'eval_batch_size': 32, 'eval_steps': 10, 'start_delay_secs': 60, 'throttle_secs': 120, 'height': 32, 'width': 32, 'depth': 3, 'base_num_filters': [512, 512], 'base_kernel_sizes': [4, 3], 'base_strides': [1, 1], 'num_steps_until_growth': 100, 'growth_num_filters': [[512, 512], [512, 512]], 'growth_kernel_sizes': [[3, 3], [3, 3]], 'growth_strides': [[1, 1], [1, 1]], 'latent_size': 512, 'generator_projection_dims': [4, 4, 512], 'generator_l1_regularization_scale': 0.01, 'generator_l2_regularization_scale': 0.01, 'generator_optimizer': 'Adam', 'generator_learning_rate': 0.0001, 'generator_clip_gradients': 5.0, 'generator_train_steps': 1, 'discriminator_l1_regularization_scale': 0.01, 'discriminator_l2_regularization_scale': 0.01, 'discriminator_optimizer': 'Adam', 'discriminator_learning_rate': 0.0001, 'discriminator_clip_gradients': 5.0, 'discriminator_gradient_penalty_coefficient': 10.0, 'discriminator_train_steps': 5}
# pgan_model: alpha_var = <tf.Variable 'alpha_var:0' shape=() dtype=float32_ref>
#
# Call generator with Z = Tensor("random_normal:0", shape=(?, 512), dtype=float32).
#
# generator_network: Z = Tensor("random_normal:0", shape=(?, 512), dtype=float32)
# generator_network: projection = Tensor("generator/projection_layer/LeakyRelu:0", shape=(?, 8192), dtype=float32)
# generator_network: base_network = Tensor("generator/projection_reshaped:0", shape=(?, 4, 4, 512), dtype=float32)
#
# create_generator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce410>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db3990>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db3410>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dabbd0>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2090>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2350>]
# generator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce410>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db3990>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db3410>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dabbd0>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2090>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2350>]]
#
# create_generator_to_rgb_layers: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dceb50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2610>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2790>]
# generator_network: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dceb50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2610>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750db2790>]
#
# create_base_generator_network: to_rgb_conv = Tensor("generator/base_to_rgb_layers_conv2d/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_0:0", shape=(?, ?, ?, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator_1/growth_upsampled_image_2/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_1:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_final_generator_network: to_rgb_conv = Tensor("generator/growth_to_rgb_layers_conv2d_1/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
# generator_network: generated_outputs = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# resize_real_images: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
#
# resize_real_image: block_idx = 0
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_0/ResizeNearestNeighbor:0", shape=(?, 4, 4, 3), dtype=float32)
#
# resize_real_image: block_idx = 1
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_1/ResizeNearestNeighbor:0", shape=(?, 8, 8, 3), dtype=float32)
#
# resize_real_image: block_idx = 2
# resize_real_image: image = Tensor("sub:0", shape=(?, 32, 32, 3), dtype=float32)
# resize_real_images: resized_image = Tensor("resize_real_images_resized_image_2/ResizeNearestNeighbor:0", shape=(?, 16, 16, 3), dtype=float32)
# resize_real_images: selected resized_image = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# Call discriminator with real_image = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32).
#
# discriminator_network: X = Tensor("resize_real_images_switch_case_resized_image/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_discriminator_from_rgb_layers: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dbdb50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dbd790>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750edfad0>]
# discriminator_network: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dbdb50>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dbd790>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750edfad0>]
#
# create_discriminator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce290>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce410>]
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dcebd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d1450>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe750ebd2d0>
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d19d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d1a50>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1c10>
# discriminator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce290>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dce410>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe750dcebd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d1450>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe750ebd2d0>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d19d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280d1a50>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1c10>]]
#
# create_discriminator_growth_transition_downsample_layers: downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe750dbd5d0>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1d90>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1f10>]
# discriminator_network: transition_downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe750dbd5d0>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1d90>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280d1f10>]
#
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 4, 4, 512), dtype=float32)
# create_base_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 8192), dtype=float32)
# create_base_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_base/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 8, 8, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 32768), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_0/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_1/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_final_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_final_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_final/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Call discriminator with generator_outputs = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32).
#
# discriminator_network: X = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_discriminator_from_rgb_layers: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280ed1d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe71c7d0e10>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280dbc10>]
# discriminator_network: from_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280ed1d0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe71c7d0e10>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280dbc10>]
#
# create_discriminator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728086210>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280aa550>]
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7519dd350>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728053510>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280b4310>
#
# create_discriminator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728061810>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe71c73bfd0>]
# create_discriminator_growth_layer_block: downsampled_image_layer = <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c7ee790>
# discriminator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728086210>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7280aa550>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe7519dd350>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728053510>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe7280b4310>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe728061810>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe71c73bfd0>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c7ee790>]]
#
# create_discriminator_growth_transition_downsample_layers: downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c7c1910>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe728067890>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c748f10>]
# discriminator_network: transition_downsample_layers = [<tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c7c1910>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe728067890>, <tensorflow.python.layers.pooling.AveragePooling2D object at 0x7fe71c748f10>]
#
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_base_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 4, 4, 512), dtype=float32)
# create_base_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 8192), dtype=float32)
# create_base_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_base/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 8, 8, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 32768), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_0/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_growth_transition_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_growth_transition_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_transition_1/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, ?, ?, 512), dtype=float32)
# create_final_discriminator_network: block_conv = Tensor("discriminator/base_layers_conv2d_0/LeakyRelu:0", shape=(?, 16, 16, 512), dtype=float32)
# create_final_discriminator_network: block_conv_flat = Tensor("discriminator/flatten/Reshape:0", shape=(?, 131072), dtype=float32)
# create_final_discriminator_network: logits = Tensor("discriminator/layers_dense_logits_final/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# get_generator_loss: generator_loss = Tensor("Neg:0", shape=(), dtype=float32)
# get_generator_loss: generator_regularization_loss = 0
# get_generator_loss: generator_total_loss = Tensor("generator_total_loss:0", shape=(), dtype=float32)
#
# get_discriminator_loss: discriminator_real_loss = Tensor("discriminator_2/discriminator_real_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_generated_loss = Tensor("discriminator_2/discriminator_generated_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_loss = Tensor("discriminator_2/discriminator_loss:0", shape=(), dtype=float32)
# get_discriminator_loss: discriminator_regularization_loss = 0
# get_discriminator_loss: discriminator_total_loss = Tensor("discriminator_2/discriminator_total_loss:0", shape=(), dtype=float32)
# serving_input_fn: feature_placeholders = {'Z': <tf.Tensor 'serving_input_placeholder_Z:0' shape=(?, 512) dtype=float32>}
# serving_input_fn: features = {'Z': <tf.Tensor 'serving_input_fn_identity_placeholder_Z:0' shape=(?, 512) dtype=float32>}
#
# pgan_model: features = {'Z': <tf.Tensor 'serving_input_fn_identity_placeholder_Z:0' shape=(?, 512) dtype=float32>}
# pgan_model: labels = None
# pgan_model: mode = infer
# pgan_model: params = {'train_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/train*.tfrecord', 'eval_file_pattern': 'gs://machine-learning-1234-bucket/gan/pgan/data/test*.tfrecord', 'output_dir': 'gs://machine-learning-1234-bucket/gan/pgan/trained_model/', 'train_batch_size': 32, 'train_steps': 20, 'eval_batch_size': 32, 'eval_steps': 10, 'start_delay_secs': 60, 'throttle_secs': 120, 'height': 32, 'width': 32, 'depth': 3, 'base_num_filters': [512, 512], 'base_kernel_sizes': [4, 3], 'base_strides': [1, 1], 'num_steps_until_growth': 100, 'growth_num_filters': [[512, 512], [512, 512]], 'growth_kernel_sizes': [[3, 3], [3, 3]], 'growth_strides': [[1, 1], [1, 1]], 'latent_size': 512, 'generator_projection_dims': [4, 4, 512], 'generator_l1_regularization_scale': 0.01, 'generator_l2_regularization_scale': 0.01, 'generator_optimizer': 'Adam', 'generator_learning_rate': 0.0001, 'generator_clip_gradients': 5.0, 'generator_train_steps': 1, 'discriminator_l1_regularization_scale': 0.01, 'discriminator_l2_regularization_scale': 0.01, 'discriminator_optimizer': 'Adam', 'discriminator_learning_rate': 0.0001, 'discriminator_clip_gradients': 5.0, 'discriminator_gradient_penalty_coefficient': 10.0, 'discriminator_train_steps': 5}
# pgan_model: alpha_var = <tf.Variable 'alpha_var:0' shape=() dtype=float32_ref>
#
# generator_network: Z = Tensor("serving_input_fn_identity_placeholder_Z:0", shape=(?, 512), dtype=float32)
# generator_network: projection = Tensor("generator/projection_layer/LeakyRelu:0", shape=(?, 8192), dtype=float32)
# generator_network: base_network = Tensor("generator/projection_reshaped:0", shape=(?, 4, 4, 512), dtype=float32)
#
# create_generator_base_conv_layer_block: base_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219cd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219f90>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e421c110>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e42238d0>]
#
# create_generator_growth_layer_block: conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226050>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226250>]
# generator_network: blocks = [[<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219cd0>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219f90>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e421c110>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e42238d0>], [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226050>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226250>]]
#
# create_generator_to_rgb_layers: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219910>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226510>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226690>]
# generator_network: to_rgb_conv_layers = [<tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4219910>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226510>, <tensorflow.python.layers.convolutional.Conv2D object at 0x7fe6e4226690>]
#
# create_base_generator_network: to_rgb_conv = Tensor("generator/base_to_rgb_layers_conv2d/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_0:0", shape=(?, ?, ?, 3), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator/growth_upsampled_image_1/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# upsample_generator_image: upsampled_image = Tensor("generator/generator_1/growth_upsampled_image_2/ResizeNearestNeighbor:0", shape=(?, ?, ?, 512), dtype=float32)
#
# create_base_generator_network: weighted_sum = Tensor("generator/growth_transition_weighted_sum_1:0", shape=(?, ?, ?, 3), dtype=float32)
#
# create_final_generator_network: to_rgb_conv = Tensor("generator/growth_to_rgb_layers_conv2d_1/LeakyRelu:0", shape=(?, 4, 4, 3), dtype=float32)
# generator_network: generated_outputs = Tensor("generator/generator_switch_case_generated_outputs/indexed_case/Identity:0", shape=(?, ?, ?, 3), dtype=float32)
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/model.py:18: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/model.py:18: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'gs://machine-learning-1234-bucket/gan/pgan/trained_model/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe76a6b0590>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/input.py:80: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/input.py:92: shuffle_and_repeat (from tensorflow.contrib.data.python.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.shuffle_and_repeat(...)`.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/contrib/data/python/ops/shuffle_ops.py:54: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/input.py:104: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/contrib/data/python/ops/batching.py:276: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/input.py:112: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:171: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:318: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:318: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:339: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:30: The name tf.layers.Conv2D is deprecated. Please use tf.compat.v1.layers.Conv2D instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:385: The name tf.floordiv is deprecated. Please use tf.math.floordiv instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/generator.py:386: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/discriminator.py:135: The name tf.layers.AveragePooling2D is deprecated. Please use tf.compat.v1.layers.AveragePooling2D instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/discriminator.py:226: The name tf.layers.Flatten is deprecated. Please use tf.compat.v1.layers.Flatten instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/discriminator.py:234: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/discriminator.py:567: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:258: The name tf.mod is deprecated. Please use tf.math.mod instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:275: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:275: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:24: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:25: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:26: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:27: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:28: The name tf.train.FtrlOptimizer is deprecated. Please use tf.compat.v1.train.FtrlOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:29: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:30: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:31: The name tf.train.ProximalAdagradOptimizer is deprecated. Please use tf.compat.v1.train.ProximalAdagradOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:32: The name tf.train.ProximalGradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.ProximalGradientDescentOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:33: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:68: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2020-06-01 10:01:33.705163: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-06-01 10:01:33.706317: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55dd698343b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 10:01:33.706356: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-01 10:01:33.706460: I tensorflow/core/common_runtime/process_util.cc:136] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://machine-learning-1234-bucket/gan/pgan/trained_model/model.ckpt.
# INFO:tensorflow:loss = 0.07782528, step = 1
# INFO:tensorflow:Saving checkpoints for 20 into gs://machine-learning-1234-bucket/gan/pgan/trained_model/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:322: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:327: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:332: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/pgan.py:337: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-01T10:03:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://machine-learning-1234-bucket/gan/pgan/trained_model/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2020-06-01-10:03:35
# INFO:tensorflow:Saving dict for global step 20: accuracy = 0.0, auc_pr = 0.3047436, auc_roc = 0.14591797, global_step = 20, loss = 83213.586, precision = 0.5, recall = 1.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20: gs://machine-learning-1234-bucket/gan/pgan/trained_model/model.ckpt-20
# WARNING:tensorflow:From /home/jupyter/artificial_intelligence/machine_learning/gan/pgan/tf_pgan/pgan_module/trainer/serving.py:18: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_export_outputs', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from gs://machine-learning-1234-bucket/gan/pgan/trained_model/model.ckpt-20
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://machine-learning-1234-bucket/gan/pgan/trained_model/export/exporter/temp-b'1591005818'/saved_model.pb
# INFO:tensorflow:Loss for final step: 99853.984.
