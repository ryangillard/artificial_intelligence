# %%
# Import libraries and modules
import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
print(np.__version__)
print(tf.__version__)
np.set_printoptions(threshold=np.inf)
# Out:
# 1.18.5
# 2.2.0-dlenv

# %% [markdown]
# # Local Development

# %% [markdown]
# ## Arguments

# %%
arguments = {}
# File arguments.
arguments["train_file_pattern"] = "gs://machine-learning-1234-bucket/gan/data/mnist/train*.tfrecord"
arguments["eval_file_pattern"] = "gs://machine-learning-1234-bucket/gan/data/mnist/test*.tfrecord"
arguments["output_dir"] = "gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model"

# Training parameters.
arguments["tf_version"] = 2.2
arguments["use_graph_mode"] = True
arguments["distribution_strategy"] = ""
arguments["write_summaries"] = False
arguments["num_epochs"] = 30
arguments["train_dataset_length"] = 60000
arguments["train_batch_size"] = 32
arguments["log_step_count_steps"] = 100
arguments["save_summary_steps"] = 100
arguments["save_checkpoints_steps"] = 10000
arguments["keep_checkpoint_max"] = 10
arguments["input_fn_autotune"] = False

# Eval parameters.
arguments["eval_batch_size"] = 32
arguments["eval_steps"] = 100

# Image parameters.
arguments["height"] = 28
arguments["width"] = 28
arguments["depth"] = 1

# Generator parameters.
arguments["latent_size"] = 512
arguments["generator_projection_dims"] = [7, 7, 256]
arguments["generator_num_filters"] = [128, 128, arguments["depth"]]
arguments["generator_kernel_sizes"] = [4, 4, 3]
arguments["generator_strides"] = [2, 2, 1]
arguments["generator_leaky_relu_alpha"] = 0.2
arguments["generator_final_activation"] = "tanh"
arguments["generator_l1_regularization_scale"] = 0.
arguments["generator_l2_regularization_scale"] = 0.
arguments["generator_optimizer"] = "Adam"
arguments["generator_learning_rate"] = 0.0002
arguments["generator_adam_beta1"] = 0.5
arguments["generator_adam_beta2"] = 0.999
arguments["generator_adam_epsilon"] = 1e-8
arguments["generator_clip_gradients"] = None
arguments["generator_train_steps"] = 1

# Discriminator hyperparameters.
arguments["discriminator_num_filters"] = [64, 128, 128, 256]
arguments["discriminator_kernel_sizes"] = [3, 3, 3, 3]
arguments["discriminator_strides"] = [1, 2, 2, 2]
arguments["discriminator_dropout_rates"] = [0.3, 0.3, 0.3, 0.3]
arguments["discriminator_leaky_relu_alpha"] = 0.2
arguments["discriminator_l1_regularization_scale"] = 0.
arguments["discriminator_l2_regularization_scale"] = 0.
arguments["discriminator_optimizer"] = "Adam"
arguments["discriminator_learning_rate"] = 0.0002
arguments["discriminator_adam_beta1"] = 0.5
arguments["discriminator_adam_beta2"] = 0.999
arguments["discriminator_adam_epsilon"] = 1e-8
arguments["discriminator_clip_gradients"] = None
arguments["discriminator_train_steps"] = 1
arguments["label_smoothing"] = 0.9

# %% [markdown]
# ## input.py

# %%
def preprocess_image(image):
    """Preprocess image tensor.

    Args:
        image: tensor, input image with shape
            [batch_size, height, width, depth].

    Returns:
        Preprocessed image tensor with shape
            [batch_size, height, width, depth].
    """
    # Convert from [0, 255] -> [-1.0, 1.0] floats.
    image = tf.cast(x=image, dtype=tf.float32) * (2. / 255) - 1.0

    return image


def decode_example(protos, params):
    """Decodes TFRecord file into tensors.

    Given protobufs, decode into image and label tensors.

    Args:
        protos: protobufs from TFRecord file.
        params: dict, user passed parameters.

    Returns:
        Image and label tensors.
    """
    # Create feature schema map for protos.
    features = {
        "image_raw": tf.io.FixedLenFeature(shape=[], dtype=tf.string),
        "label": tf.io.FixedLenFeature(shape=[], dtype=tf.int64)
    }

    # Parse features from tf.Example.
    parsed_features = tf.io.parse_single_example(
        serialized=protos, features=features
    )

    # Convert from a scalar string tensor (whose single string has
    # length height * width * depth) to a uint8 tensor with shape
    # [height * width * depth].
    image = tf.io.decode_raw(
        input_bytes=parsed_features["image_raw"], out_type=tf.uint8
    )

    # Reshape flattened image back into normal dimensions.
    image = tf.reshape(
        tensor=image,
        shape=[params["height"], params["width"], params["depth"]]
    )

    # Preprocess image.
    image = preprocess_image(image=image)

    # Convert label from a scalar uint8 tensor to an int32 scalar.
    label = tf.cast(x=parsed_features["label"], dtype=tf.int32)

    return {"image": image}, label


def read_dataset(filename, batch_size, params, training):
    """Reads TF Record data using tf.data, doing necessary preprocessing.

    Given filename, mode, batch size, and other parameters, read TF Record
    dataset using Dataset API, apply necessary preprocessing, and return an
    input function to the Estimator API.

    Args:
        filename: str, file pattern that to read into our tf.data dataset.
        batch_size: int, number of examples per batch.
        params: dict, dictionary of user passed parameters.
        training: bool, if training or not.

    Returns:
        An input function.
    """
    def _input_fn():
        """Wrapper input function used by Estimator API to get data tensors.

        Returns:
            Batched dataset object of dictionary of feature tensors and label
                tensor.
        """
        # Create list of files that match pattern.
        file_list = tf.data.Dataset.list_files(file_pattern=filename)

        # Create dataset from file list.
        dataset = tf.data.TFRecordDataset(
            filenames=file_list,
            num_parallel_reads=(
                tf.contrib.data.AUTOTUNE
                if params["input_fn_autotune"]
                else None
            )
        )

        # Shuffle and repeat if training with fused op.
        if training:
            dataset = dataset.apply(
                tf.data.experimental.shuffle_and_repeat(
                    buffer_size=50 * batch_size,
                    count=None  # indefinitely
                )
            )

        # Decode CSV file into a features dictionary of tensors, then batch.
        dataset = dataset.apply(
            tf.data.experimental.map_and_batch(
                map_func=lambda x: decode_example(
                    protos=x,
                    params=params
                ),
                batch_size=batch_size,
                num_parallel_calls=(
                    tf.contrib.data.AUTOTUNE
                    if params["input_fn_autotune"]
                    else None
                )
            )
        )

        # Prefetch data to improve latency.
        dataset = dataset.prefetch(
            buffer_size=(
                tf.data.experimental.AUTOTUNE
                if params["input_fn_autotune"]
                else 1
            )
        )

        return dataset
    return _input_fn

# %%
train_ds = read_dataset(
    filename=arguments["train_file_pattern"],
    batch_size=arguments["train_batch_size"],
    params=arguments,
    training=True
)()
train_ds
# Out:
# WARNING:tensorflow:From <ipython-input-3-80a3e8a164a2>:104: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From <ipython-input-3-80a3e8a164a2>:119: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# <PrefetchDataset shapes: ({image: (None, 28, 28, 1)}, (None,)), types: ({image: tf.float32}, tf.int32)>

# %%
eval_ds = read_dataset(
    filename=arguments["eval_file_pattern"],
    batch_size=arguments["eval_batch_size"],
    params=arguments,
    training=False
)()
eval_ds
# Out:
# <PrefetchDataset shapes: ({image: (None, 28, 28, 1)}, (None,)), types: ({image: tf.float32}, tf.int32)>

# %% [markdown]
# ## generators.py

# %%
class Generator(object):
    """Generator that takes latent vector input and outputs image.

    Fields:
        name: str, name of `Generator`.
        kernel_regularizer: `l1_l2_regularizer` object, regularizar for
            kernel variables.
        bias_regularizer: `l1_l2_regularizer` object, regularizar for bias
            variables.
        params: dict, user passed parameters.
        model: instance of generator `Model`.
    """
    def __init__(
            self,
            input_shape,
            kernel_regularizer,
            bias_regularizer,
            name,
            params):
        """Instantiates and builds generator network.

        Args:
            input_shape: tuple, shape of latent vector input of shape
                [batch_size, latent_size].
            kernel_regularizer: `l1_l2_regularizer` object, regularizar for
                kernel variables.
            bias_regularizer: `l1_l2_regularizer` object, regularizar for bias
                variables.
            name: str, name of generator.
            params: dict, user passed parameters.
        """
        # Set name of generator.
        self.name = name

        # Store regularizers.
        self.kernel_regularizer = kernel_regularizer
        self.bias_regularizer = bias_regularizer

        # Store parameters.
        self.params = params

        # Instantiate generator `Model`.
        self.model = self._define_generator(input_shape)

    def _project_latent_vectors(self, latent_vectors):
        """Defines generator network.

        Args:
            latent_vectors: tensor, latent vector inputs of shape
                [batch_size, latent_size].

        Returns:
            Projected image of latent vector inputs.
        """
        projection_height = self.params["generator_projection_dims"][0]
        projection_width = self.params["generator_projection_dims"][1]
        projection_depth = self.params["generator_projection_dims"][2]

        # shape = (
        #     batch_size,
        #     projection_height * projection_width * projection_depth
        # )
        projection = tf.keras.layers.Dense(
            units=projection_height * projection_width * projection_depth,
            activation=None,
            kernel_regularizer=self.kernel_regularizer,
            bias_regularizer=self.bias_regularizer,
            name="projection_dense_layer"
        )(inputs=latent_vectors)

        projection_leaky_relu = tf.keras.layers.LeakyReLU(
            alpha=self.params["generator_leaky_relu_alpha"],
            name="projection_leaky_relu"
        )(inputs=projection)

        # Add batch normalization to keep the inputs from blowing up.
        # shape = (
        #     batch_size,
        #     projection_height * projection_width * projection_depth
        # )
        projection_batch_norm = tf.keras.layers.BatchNormalization(
            name="projection_batch_norm"
        )(inputs=projection_leaky_relu)

        # Reshape projection into "image".
        # shape = (
        #     batch_size,
        #     projection_height,
        #     projection_width,
        #     projection_depth
        # )
        projected_image = tf.reshape(
            tensor=projection_batch_norm,
            shape=[
                -1, projection_height, projection_width, projection_depth
            ],
            name="projected_image"
        )

        return projected_image

    def _define_generator(
            self, input_shape):
        """Defines generator network.

        Args:
            input_shape: tuple, shape of latent vector input of shape
                [batch_size, latent_size].

        Returns:
            Instance of `Model` object.
        """
        # Create the input layer to generator.
        # shape = (batch_size, latent_size)
        inputs = tf.keras.Input(
            shape=input_shape, name="{}_inputs".format(self.name)
        )

        # Dictionary containing possible final activations.
        final_activation_set = {"sigmoid", "relu", "tanh"}

        # Project latent vectors.
        network = self._project_latent_vectors(latent_vectors=inputs)

        # Iteratively build upsampling layers.
        for i in range(len(self.params["generator_num_filters"]) - 1):
            # Add conv transpose layers with given params per layer.
            # shape = (
            #     batch_size,
            #     generator_kernel_sizes[i - 1] * generator_strides[i],
            #     generator_kernel_sizes[i - 1] * generator_strides[i],
            #     generator_num_filters[i]
            # )
            network = tf.keras.layers.Conv2DTranspose(
                filters=self.params["generator_num_filters"][i],
                kernel_size=self.params["generator_kernel_sizes"][i],
                strides=self.params["generator_strides"][i],
                padding="same",
                activation=None,
                kernel_regularizer=self.kernel_regularizer,
                bias_regularizer=self.bias_regularizer,
                name="{}_layers_conv2d_tranpose_{}".format(self.name, i)
            )(inputs=network)

            network = tf.keras.layers.LeakyReLU(
                alpha=self.params["generator_leaky_relu_alpha"],
                name="{}_leaky_relu_{}".format(self.name, i)
            )(inputs=network)

            # Add batch normalization to keep the inputs from blowing up.
            network = tf.keras.layers.BatchNormalization(
                name="{}_layers_batch_norm_{}".format(self.name, i)
            )(inputs=network)

        # Final conv2d transpose layer for image output.
        # shape = (batch_size, height, width, depth)
        fake_images = tf.keras.layers.Conv2DTranspose(
            filters=self.params["generator_num_filters"][-1],
            kernel_size=self.params["generator_kernel_sizes"][-1],
            strides=self.params["generator_strides"][-1],
            padding="same",
            activation=(
                self.params["generator_final_activation"].lower()
                if self.params["generator_final_activation"].lower()
                in final_activation_set
                else None
            ),
            kernel_regularizer=self.kernel_regularizer,
            bias_regularizer=self.bias_regularizer,
            name="{}_layers_conv2d_tranpose_fake_images".format(self.name)
        )(inputs=network)

        # Resize fake images to match real images in case of mismatch.
        height = self.params["height"]
        width = self.params["width"]
        fake_images = tf.keras.layers.Lambda(
            function=lambda x: tf.image.resize(
                images=x, size=[height, width], method="bilinear"
            ),
            name="{}_resize_fake_images".format(self.name)
        )(inputs=fake_images)

        # Define model.
        model = tf.keras.Model(
            inputs=inputs, outputs=fake_images, name=self.name
        )

        return model

    def get_model(self):
        """Returns generator's `Model` object.

        Returns:
            Generator's `Model` object.
        """
        return self.model

    def get_generator_loss(
        self,
        global_batch_size,
        fake_logits,
        global_step,
        summary_file_writer
    ):
        """Gets generator loss.

        Args:
            global_batch_size: int, global batch size for distribution.
            fake_logits: tensor, shape of
                [batch_size, 1].
            global_step: int, current global step for training.
            summary_file_writer: summary file writer.

        Returns:
            Tensor of generator's total loss of shape [].
        """
        if self.params["distribution_strategy"]:
            # Calculate base generator loss.
            generator_loss = tf.nn.compute_average_loss(
                per_example_loss=tf.keras.losses.BinaryCrossentropy(
                    from_logits=True,
                    reduction=tf.keras.losses.Reduction.NONE
                )(
                    y_true=tf.ones_like(input=fake_logits), y_pred=fake_logits
                ),
                global_batch_size=global_batch_size
            )

            # Get regularization losses.
            generator_reg_loss = tf.nn.scale_regularization_loss(
                regularization_loss=sum(self.model.losses)
            )
        else:
            # Calculate base generator loss.
            generator_loss = tf.keras.losses.BinaryCrossentropy(
                from_logits=True
            )(
                y_true=tf.ones_like(input=fake_logits), y_pred=fake_logits
            )

            # Get regularization losses.
            generator_reg_loss = sum(self.model.losses)

        # Combine losses for total losses.
        generator_total_loss = tf.math.add(
            x=generator_loss,
            y=generator_reg_loss,
            name="generator_total_loss"
        )

        if self.params["write_summaries"]:
            # Add summaries for TensorBoard.
            with summary_file_writer.as_default():
                with tf.summary.record_if(
                    condition=tf.equal(
                        x=tf.math.floormod(
                            x=global_step,
                            y=self.params["save_summary_steps"]
                        ), y=0
                    )
                ):
                    tf.summary.scalar(
                        name="losses/generator_loss",
                        data=generator_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="losses/generator_reg_loss",
                        data=generator_reg_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="optimized_losses/generator_total_loss",
                        data=generator_total_loss,
                        step=global_step
                    )
                    summary_file_writer.flush()

        return generator_total_loss

# %%
# Instantiate generator.
dcgan_generator = Generator(
    input_shape=(arguments["latent_size"]),
    kernel_regularizer=tf.keras.regularizers.l1_l2(
        l1=arguments["generator_l1_regularization_scale"],
        l2=arguments["generator_l2_regularization_scale"]
    ),
    bias_regularizer=None,
    name="generator",
    params=arguments
)

# Define generator model.
generator_model = dcgan_generator.get_model()

# %%
# Summarize generator model.
generator_model.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_inputs (InputLayer [(None, 512)]             0
# _________________________________________________________________
# projection_dense_layer (Dens (None, 12544)             6435072
# _________________________________________________________________
# projection_leaky_relu (Leaky (None, 12544)             0
# _________________________________________________________________
# projection_batch_norm (Batch (None, 12544)             50176
# _________________________________________________________________
# tf_op_layer_projected_image  [(None, 7, 7, 256)]       0
# _________________________________________________________________
# generator_layers_conv2d_tran (None, 14, 14, 128)       524416
# _________________________________________________________________
# generator_leaky_relu_0 (Leak (None, 14, 14, 128)       0
# _________________________________________________________________
# generator_layers_batch_norm_ (None, 14, 14, 128)       512
# _________________________________________________________________
# generator_layers_conv2d_tran (None, 28, 28, 128)       262272
# _________________________________________________________________
# generator_leaky_relu_1 (Leak (None, 28, 28, 128)       0
# _________________________________________________________________
# generator_layers_batch_norm_ (None, 28, 28, 128)       512
# _________________________________________________________________
# generator_layers_conv2d_tran (None, 28, 28, 1)         1153
# _________________________________________________________________
# generator_resize_fake_images (None, 28, 28, 1)         0
# =================================================================
# Total params: 7,274,113
# Trainable params: 7,248,513
# Non-trainable params: 25,600
# _________________________________________________________________

# %%
generator_model.__dict__
# Out:
# {'_self_setattr_tracking': True,
#  '_nested_outputs': <tf.Tensor 'generator_resize_fake_images/Identity:0' shape=(None, 28, 28, 1) dtype=float32>,
#  '_nested_inputs': <tf.Tensor 'generator_inputs:0' shape=(None, 512) dtype=float32>,
#  'inputs': [<tf.Tensor 'generator_inputs:0' shape=(None, 512) dtype=float32>],
#  'outputs': [<tf.Tensor 'generator_resize_fake_images/Identity:0' shape=(None, 28, 28, 1) dtype=float32>],
#  '_enable_dict_to_input_mapping': True,
#  '_trainable': True,
#  '_stateful': False,
#  'built': True,
#  '_build_input_shape': TensorShape([None, 512]),
#  '_input_spec': None,
#  'supports_masking': False,
#  '_supports_ragged_inputs': None,
#  '_name': 'generator',
#  '_activity_regularizer': None,
#  '_trainable_weights': [],
#  '_non_trainable_weights': [],
#  '_updates': [],
#  '_thread_local': <_thread._local at 0x7f5a6c77dbf0>,
#  '_callable_losses': [],
#  '_losses': [],
#  '_metrics': [],
#  '_metrics_lock': <unlocked _thread.lock object at 0x7f5a780881b0>,
#  '_dtype_policy': <Policy "float32", loss_scale=None>,
#  '_dtype_defaulted_to_floatx': True,
#  '_autocast': False,
#  '_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5b33447150>,
#   <tensorflow.python.keras.layers.core.Dense at 0x7f5b334454d0>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5ad00377d0>,
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5b3344ab10>,
#   <tensorflow.python.keras.engine.base_layer.TensorFlowOpLayer at 0x7f5ad00343d0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5a6c735e90>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5ad003d390>,
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5ad0032e10>,
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5a78049a90>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a7817ab10>,
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5ad002c750>,
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5ae099be90>,
#   <tensorflow.python.keras.layers.core.Lambda at 0x7f5a88038a50>],
#  '_inbound_nodes': [<tensorflow.python.keras.engine.node.Node at 0x7f5a78085690>],
#  '_outbound_nodes': [],
#  '_expects_training_arg': True,
#  '_expects_mask_arg': True,
#  '_dynamic': False,
#  '_initial_weights': None,
#  '_auto_track_sub_layers': True,
#  'output_names': ['generator_resize_fake_images'],
#  'input_names': ['generator_inputs'],
#  '_is_compiled': False,
#  '_saved_model_inputs_spec': TensorSpec(shape=(None, 512), dtype=tf.float32, name='generator_inputs'),
#  '_compute_output_and_mask_jointly': True,
#  'optimizer': None,
#  '_scope': None,
#  '_reuse': None,
#  '_graph': None,
#  '_trackable_saver': <tensorflow.python.training.tracking.util.TrackableSaver at 0x7f5ad0040750>,
#  '_is_graph_network': True,
#  '_input_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5b33447150>],
#  '_output_layers': [<tensorflow.python.keras.layers.core.Lambda at 0x7f5a88038a50>],
#  '_input_coordinates': [(<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5b33447150>,
#    0,
#    0)],
#  '_output_coordinates': [(<tensorflow.python.keras.layers.core.Lambda at 0x7f5a88038a50>,
#    0,
#    0)],
#  '_output_mask_cache': {},
#  '_output_tensor_cache': {},
#  '_output_shape_cache': {},
#  '_network_nodes': {'generator_inputs_ib-0',
#   'generator_layers_batch_norm_0_ib-0',
#   'generator_layers_batch_norm_1_ib-0',
#   'generator_layers_conv2d_tranpose_0_ib-0',
#   'generator_layers_conv2d_tranpose_1_ib-0',
#   'generator_layers_conv2d_tranpose_fake_images_ib-0',
#   'generator_leaky_relu_0_ib-0',
#   'generator_leaky_relu_1_ib-0',
#   'generator_resize_fake_images_ib-0',
#   'projection_batch_norm_ib-0',
#   'projection_dense_layer_ib-0',
#   'projection_leaky_relu_ib-0',
#   'tf_op_layer_projected_image_ib-0'},
#  '_nodes_by_depth': defaultdict(list,
#              {0: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78091f90>],
#               1: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78081e10>],
#               2: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78199a10>],
#               3: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78194950>],
#               4: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78182a90>],
#               5: [<tensorflow.python.keras.engine.node.Node at 0x7f5a7804df90>],
#               6: [<tensorflow.python.keras.engine.node.Node at 0x7f5a88031c10>],
#               7: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78023a50>],
#               8: [<tensorflow.python.keras.engine.node.Node at 0x7f5ad00668d0>],
#               9: [<tensorflow.python.keras.engine.node.Node at 0x7f5a8805d410>],
#               10: [<tensorflow.python.keras.engine.node.Node at 0x7f5a88038590>],
#               11: [<tensorflow.python.keras.engine.node.Node at 0x7f5ad003d690>],
#               12: [<tensorflow.python.keras.engine.node.Node at 0x7f5ad002c650>]}),
#  '_layer_call_argspecs': {<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5b33447150>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw='kwargs', defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dense at 0x7f5b334454d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5ad00377d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5b3344ab10>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.engine.base_layer.TensorFlowOpLayer at 0x7f5ad00343d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5a6c735e90>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5ad003d390>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5ad0032e10>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5a78049a90>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a7817ab10>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f5ad002c750>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose at 0x7f5ae099be90>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Lambda at 0x7f5a88038a50>: FullArgSpec(args=['self', 'inputs', 'mask', 'training'], varargs=None, varkw=None, defaults=(None, None), kwonlyargs=[], kwonlydefaults=None, annotations={})},
#  '_feed_input_names': ['generator_inputs'],
#  '_feed_inputs': [<tf.Tensor 'generator_inputs:0' shape=(None, 512) dtype=float32>],
#  '_feed_input_shapes': [(None, 512)],
#  '_tensor_usage_count': Counter({'140028013695248': 1,
#           '140026805737360': 1,
#           '140026805736080': 1,
#           '140026537190480': 1,
#           '140026537195088': 1,
#           '140026537352336': 1,
#           '140026537369104': 1,
#           '140026538601040': 1,
#           '140026538704336': 1,
#           '140026538708816': 1,
#           '140026537545360': 1,
#           '140026537662608': 1,
#           '140026537697936': 1}),
#  '_obj_reference_counts_dict': ObjectIdentityDictionary({<_ObjectIdentityWrapper wrapping False>: 1}),
#  '_distribution_strategy': None,
#  '_run_eagerly': None,
#  'stop_training': False,
#  'train_function': None,
#  'test_function': None,
#  'predict_function': None,
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x7f5ad0037110>,
#  '_training_state': None,
#  'history': None,
#  'compiled_loss': None,
#  'compiled_metrics': None}

# %%
# Plot generator model.
tf.keras.utils.plot_model(
    model=generator_model,
    to_file="generator_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
noise = tf.random.normal(shape=[10, arguments["latent_size"]])
fake_images = generator_model(inputs=noise, training=False)

plt.imshow(fake_images[0, :, :, 0], cmap='gray')

# %% [markdown]
# ## discriminators.py

# %%
class Discriminator(object):
    """Discriminator that takes image input and outputs logits.

    Fields:
        name: str, name of `Discriminator`.
        kernel_regularizer: `l1_l2_regularizer` object, regularizar for
            kernel variables.
        bias_regularizer: `l1_l2_regularizer` object, regularizar for bias
            variables.
        params: dict, user passed parameters.
        model: instance of discriminator `Model`.
    """
    def __init__(
            self,
            input_shape,
            kernel_regularizer,
            bias_regularizer,
            name,
            params):
        """Instantiates and builds discriminator network.

        Args:
            input_shape: tuple, shape of image vector input of shape
                [batch_size, height * width * depth].
            kernel_regularizer: `l1_l2_regularizer` object, regularizar for
                kernel variables.
            bias_regularizer: `l1_l2_regularizer` object, regularizar for bias
                variables.
            name: str, name of discriminator.
            params: dict, user passed parameters.
        """
        # Set name of discriminator.
        self.name = name

        # Store regularizers.
        self.kernel_regularizer = kernel_regularizer
        self.bias_regularizer = bias_regularizer

        # Store parameters.
        self.params = params

        # Instantiate discriminator `Model`.
        self.model = self._define_discriminator(input_shape)

    def _define_discriminator(self, input_shape):
        """Defines discriminator network.

        Args:
            input_shape: tuple, shape of image vector input of shape
                [batch_size, height * width * depth].

        Returns:
            Instance of `Model` object.
        """
        # Create the input layer to discriminator.
        # shape = (batch_size, height * width * depth)
        inputs = tf.keras.Input(
            shape=input_shape,
            name="{}_inputs".format(self.name)
        )
        network = inputs

        # Iteratively build downsampling layers.
        for i in range(len(self.params["discriminator_num_filters"])):
            # Add convolutional layers with given params per layer.
            # shape = (
            #     batch_size,
            #     discriminator_kernel_sizes[i - 1] / discriminator_strides[i],
            #     discriminator_kernel_sizes[i - 1] / discriminator_strides[i],
            #     discriminator_num_filters[i]
            # )
            network = tf.keras.layers.Conv2D(
                filters=self.params["discriminator_num_filters"][i],
                kernel_size=self.params["discriminator_kernel_sizes"][i],
                strides=self.params["discriminator_strides"][i],
                padding="same",
                activation=None,
                kernel_regularizer=self.kernel_regularizer,
                bias_regularizer=self.bias_regularizer,
                name="{}_layers_conv2d_{}".format(self.name, i)
            )(inputs=network)

            network = tf.keras.layers.LeakyReLU(
                alpha=self.params["discriminator_leaky_relu_alpha"],
                name="{}_leaky_relu_{}".format(self.name, i)
            )(inputs=network)

            # Add some dropout for better regularization and stability.
            network = tf.keras.layers.Dropout(
                rate=self.params["discriminator_dropout_rates"][i],
                name="{}_layers_dropout_{}".format(self.name, i)
            )(inputs=network)

        # Flatten network output.
        # shape = (
        #     batch_size,
        #     (discriminator_kernel_sizes[-2] / discriminator_strides[-1]) ** 2 * discriminator_num_filters[-1]
        # )
        network = tf.keras.layers.Flatten()(inputs=network)

        # Final linear layer for logits.
        # shape = (batch_size, 1)
        logits = tf.keras.layers.Dense(
            units=1,
            activation=None,
            kernel_regularizer=self.kernel_regularizer,
            bias_regularizer=self.bias_regularizer,
            name="{}_layers_dense_logits".format(self.name)
        )(inputs=network)

        # Define model.
        model = tf.keras.Model(
            inputs=inputs, outputs=logits, name=self.name
        )

        return model

    def get_model(self):
        """Returns discriminator's `Model` object.

        Returns:
            Discriminator's `Model` object.
        """
        return self.model

    def get_discriminator_loss(
        self,
        global_batch_size,
        fake_logits,
        real_logits,
        global_step,
        summary_file_writer
    ):
        """Gets discriminator loss.

        Args:
            global_batch_size: int, global batch size for distribution.
            fake_logits: tensor, shape of
                [batch_size, 1].
            real_logits: tensor, shape of
                [batch_size, 1].
            global_step: int, current global step for training.
            summary_file_writer: summary file writer.

        Returns:
            Tensor of discriminator's total loss of shape [].
        """
        if self.params["distribution_strategy"]:
            # Calculate base discriminator loss.
            discriminator_real_loss = tf.nn.compute_average_loss(
                per_example_loss=tf.keras.losses.BinaryCrossentropy(
                    from_logits=True,
                    label_smoothing=self.params["label_smoothing"],
                    reduction=tf.keras.losses.Reduction.NONE
                )(
                    y_true=tf.ones_like(input=real_logits), y_pred=real_logits
                ),
                global_batch_size=global_batch_size
            )

            discriminator_fake_loss = tf.nn.compute_average_loss(
                per_example_loss=tf.keras.losses.BinaryCrossentropy(
                    from_logits=True,
                    reduction=tf.keras.losses.Reduction.NONE
                )(
                    y_true=tf.zeros_like(input=fake_logits), y_pred=fake_logits
                ),
                global_batch_size=global_batch_size
            )
        else:
            # Calculate base discriminator loss.
            discriminator_real_loss = tf.keras.losses.BinaryCrossentropy(
                from_logits=True,
                label_smoothing=self.params["label_smoothing"]
            )(
                y_true=tf.ones_like(input=real_logits), y_pred=real_logits
            )

            discriminator_fake_loss = tf.keras.losses.BinaryCrossentropy(
                from_logits=True
            )(
                y_true=tf.zeros_like(input=fake_logits), y_pred=fake_logits
            )

        discriminator_loss = tf.math.add(
            x=discriminator_real_loss,
            y=discriminator_fake_loss,
            name="discriminator_loss"
        )

        if self.params["distribution_strategy"]:
            # Get regularization losses.
            discriminator_reg_loss = tf.nn.scale_regularization_loss(
                regularization_loss=sum(self.model.losses)
            )
        else:
            # Get regularization losses.
            discriminator_reg_loss = sum(self.model.losses)

        # Combine losses for total losses.
        discriminator_total_loss = tf.math.add(
            x=discriminator_loss,
            y=discriminator_reg_loss,
            name="discriminator_total_loss"
        )

        if self.params["write_summaries"]:
            # Add summaries for TensorBoard.
            with summary_file_writer.as_default():
                with tf.summary.record_if(
                    condition=tf.equal(
                        x=tf.math.floormod(
                            x=global_step,
                            y=self.params["save_summary_steps"]
                        ), y=0
                    )
                ):
                    tf.summary.scalar(
                        name="losses/discriminator_real_loss",
                        data=discriminator_real_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="losses/discriminator_fake_loss",
                        data=discriminator_fake_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="losses/discriminator_loss",
                        data=discriminator_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="losses/discriminator_reg_loss",
                        data=discriminator_reg_loss,
                        step=global_step
                    )
                    tf.summary.scalar(
                        name="optimized_losses/discriminator_total_loss",
                        data=discriminator_total_loss,
                        step=global_step
                    )
                    summary_file_writer.flush()

        return discriminator_total_loss

# %%
# Instantiate discriminator.
dcgan_discriminator = Discriminator(
    input_shape=(arguments["height"], arguments["width"], arguments["depth"]),
    kernel_regularizer=tf.keras.regularizers.l1_l2(
        l1=arguments["discriminator_l1_regularization_scale"],
        l2=arguments["discriminator_l2_regularization_scale"]
    ),
    bias_regularizer=None,
    name="discriminator",
    params=arguments
)

# Define discriminator model.
discriminator_model = dcgan_discriminator.get_model()

# %%
# Summarize discriminator model.
discriminator_model.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_inputs (InputL [(None, 28, 28, 1)]       0
# _________________________________________________________________
# discriminator_layers_conv2d_ (None, 28, 28, 64)        640
# _________________________________________________________________
# discriminator_leaky_relu_0 ( (None, 28, 28, 64)        0
# _________________________________________________________________
# discriminator_layers_dropout (None, 28, 28, 64)        0
# _________________________________________________________________
# discriminator_layers_conv2d_ (None, 14, 14, 128)       73856
# _________________________________________________________________
# discriminator_leaky_relu_1 ( (None, 14, 14, 128)       0
# _________________________________________________________________
# discriminator_layers_dropout (None, 14, 14, 128)       0
# _________________________________________________________________
# discriminator_layers_conv2d_ (None, 7, 7, 128)         147584
# _________________________________________________________________
# discriminator_leaky_relu_2 ( (None, 7, 7, 128)         0
# _________________________________________________________________
# discriminator_layers_dropout (None, 7, 7, 128)         0
# _________________________________________________________________
# discriminator_layers_conv2d_ (None, 4, 4, 256)         295168
# _________________________________________________________________
# discriminator_leaky_relu_3 ( (None, 4, 4, 256)         0
# _________________________________________________________________
# discriminator_layers_dropout (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# discriminator_layers_dense_l (None, 1)                 4097
# =================================================================
# Total params: 521,345
# Trainable params: 521,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_model.__dict__
# Out:
# {'_self_setattr_tracking': True,
#  '_nested_outputs': <tf.Tensor 'discriminator_layers_dense_logits/Identity:0' shape=(None, 1) dtype=float32>,
#  '_nested_inputs': <tf.Tensor 'discriminator_inputs:0' shape=(None, 28, 28, 1) dtype=float32>,
#  'inputs': [<tf.Tensor 'discriminator_inputs:0' shape=(None, 28, 28, 1) dtype=float32>],
#  'outputs': [<tf.Tensor 'discriminator_layers_dense_logits/Identity:0' shape=(None, 1) dtype=float32>],
#  '_enable_dict_to_input_mapping': True,
#  '_trainable': True,
#  '_stateful': False,
#  'built': True,
#  '_build_input_shape': TensorShape([None, 28, 28, 1]),
#  '_input_spec': None,
#  'supports_masking': False,
#  '_supports_ragged_inputs': None,
#  '_name': 'discriminator',
#  '_activity_regularizer': None,
#  '_trainable_weights': [],
#  '_non_trainable_weights': [],
#  '_updates': [],
#  '_thread_local': <_thread._local at 0x7f5a6c643b90>,
#  '_callable_losses': [],
#  '_losses': [],
#  '_metrics': [],
#  '_metrics_lock': <unlocked _thread.lock object at 0x7f5a6c693f30>,
#  '_dtype_policy': <Policy "float32", loss_scale=None>,
#  '_dtype_defaulted_to_floatx': True,
#  '_autocast': False,
#  '_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5a7812d210>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a6c7c8290>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780dfe50>,
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a6c7cb310>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a7812a650>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780e9b90>,
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a7813ca90>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a780e90d0>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780ec490>,
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5ae16045d0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5ae1605190>,
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a6c7b5810>,
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a780deb90>,
#   <tensorflow.python.keras.layers.core.Flatten at 0x7f5ae0a92850>,
#   <tensorflow.python.keras.layers.core.Dense at 0x7f5a6c6d28d0>],
#  '_inbound_nodes': [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7c88d0>],
#  '_outbound_nodes': [],
#  '_expects_training_arg': True,
#  '_expects_mask_arg': True,
#  '_dynamic': False,
#  '_initial_weights': None,
#  '_auto_track_sub_layers': True,
#  'output_names': ['discriminator_layers_dense_logits'],
#  'input_names': ['discriminator_inputs'],
#  '_is_compiled': False,
#  '_saved_model_inputs_spec': TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='discriminator_inputs'),
#  '_compute_output_and_mask_jointly': True,
#  'optimizer': None,
#  '_scope': None,
#  '_reuse': None,
#  '_graph': None,
#  '_trackable_saver': <tensorflow.python.training.tracking.util.TrackableSaver at 0x7f5a6c644950>,
#  '_is_graph_network': True,
#  '_input_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5a7812d210>],
#  '_output_layers': [<tensorflow.python.keras.layers.core.Dense at 0x7f5a6c6d28d0>],
#  '_input_coordinates': [(<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5a7812d210>,
#    0,
#    0)],
#  '_output_coordinates': [(<tensorflow.python.keras.layers.core.Dense at 0x7f5a6c6d28d0>,
#    0,
#    0)],
#  '_output_mask_cache': {},
#  '_output_tensor_cache': {},
#  '_output_shape_cache': {},
#  '_network_nodes': {'discriminator_inputs_ib-0',
#   'discriminator_layers_conv2d_0_ib-0',
#   'discriminator_layers_conv2d_1_ib-0',
#   'discriminator_layers_conv2d_2_ib-0',
#   'discriminator_layers_conv2d_3_ib-0',
#   'discriminator_layers_dense_logits_ib-0',
#   'discriminator_layers_dropout_0_ib-0',
#   'discriminator_layers_dropout_1_ib-0',
#   'discriminator_layers_dropout_2_ib-0',
#   'discriminator_layers_dropout_3_ib-0',
#   'discriminator_leaky_relu_0_ib-0',
#   'discriminator_leaky_relu_1_ib-0',
#   'discriminator_leaky_relu_2_ib-0',
#   'discriminator_leaky_relu_3_ib-0',
#   'flatten_ib-0'},
#  '_nodes_by_depth': defaultdict(list,
#              {0: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c644a90>],
#               1: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c63bf50>],
#               2: [<tensorflow.python.keras.engine.node.Node at 0x7f5ae0a91c50>],
#               3: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7aa490>],
#               4: [<tensorflow.python.keras.engine.node.Node at 0x7f5ae0a92b50>],
#               5: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7b54d0>],
#               6: [<tensorflow.python.keras.engine.node.Node at 0x7f5a7810dd50>],
#               7: [<tensorflow.python.keras.engine.node.Node at 0x7f5ae1604490>],
#               8: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7b89d0>],
#               9: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7b8a50>],
#               10: [<tensorflow.python.keras.engine.node.Node at 0x7f5a780e9310>],
#               11: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78128a90>],
#               12: [<tensorflow.python.keras.engine.node.Node at 0x7f5a78140290>],
#               13: [<tensorflow.python.keras.engine.node.Node at 0x7f5a6c7ced50>],
#               14: [<tensorflow.python.keras.engine.node.Node at 0x7f5ad0032ad0>]}),
#  '_layer_call_argspecs': {<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f5a7812d210>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw='kwargs', defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a6c7c8290>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780dfe50>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a6c7cb310>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a7812a650>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780e9b90>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a7813ca90>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5a780e90d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a780ec490>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5ae16045d0>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5ae1605190>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.advanced_activations.LeakyReLU at 0x7f5a6c7b5810>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dropout at 0x7f5a780deb90>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Flatten at 0x7f5ae0a92850>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.core.Dense at 0x7f5a6c6d28d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={})},
#  '_feed_input_names': ['discriminator_inputs'],
#  '_feed_inputs': [<tf.Tensor 'discriminator_inputs:0' shape=(None, 28, 28, 1) dtype=float32>],
#  '_feed_input_shapes': [(None, 28, 28, 1)],
#  '_tensor_usage_count': Counter({'140026538265360': 1,
#           '140026538362768': 1,
#           '140026538363856': 1,
#           '140026538005904': 1,
#           '140026343819344': 1,
#           '140026343710480': 1,
#           '140028304966608': 1,
#           '140026538154768': 1,
#           '140026343806096': 1,
#           '140028292965520': 1,
#           '140026343761424': 1,
#           '140026343741200': 1,
#           '140026342259728': 1,
#           '140026342295568': 1,
#           '140026342312784': 1}),
#  '_obj_reference_counts_dict': ObjectIdentityDictionary({<_ObjectIdentityWrapper wrapping False>: 1}),
#  '_distribution_strategy': None,
#  '_run_eagerly': None,
#  'stop_training': False,
#  'train_function': None,
#  'test_function': None,
#  'predict_function': None,
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x7f5a6c644650>,
#  '_training_state': None,
#  'history': None,
#  'compiled_loss': None,
#  'compiled_metrics': None}

# %%
# Plot discriminator model.
tf.keras.utils.plot_model(
    model=discriminator_model,
    to_file="discriminator_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
images = tf.random.normal(
    shape=[10, arguments["height"], arguments["width"], arguments["depth"]]
)
logits = discriminator_model(inputs=images, training=False)
logits.shape
# Out:
# TensorShape([10, 1])

# %% [markdown]
# ## train_and_evaluate_loop.py

# %%
class TrainAndEvaluateLoop(object):
    """Train and evaluate loop trainer.

    Fields:
        params: dict, user passed parameters.
        network_objects: dict, instances of `Generator` and `Discriminator`
            network objects.
        network_models: dict, instances of Keras `Model`s for each network.
        optimizers: dict, instances of Keras `Optimizer`s for each network.
        strategy: instance of tf.distribute.strategy.
        global_batch_size: int, the global batch size after summing batch
            sizes across replicas.
        global_step: tf.Variable, the global step counter across epochs and
            steps within epoch.
        checkpoint_manager: instance of `tf.train.CheckpointManager`.
        summary_file_writer: instance of tf.summary.create_file_writer for
            summaries for TensorBoard.
    """
    def __init__(self, params):
        """Instantiate trainer.

        Args:
            params: dict, user passed parameters.
        """
        self.params = params

        self.network_objects = {}
        self.network_models = {}
        self.optimizers = {}

        self.strategy = None

        self.global_batch_size = None
        self.global_step = tf.Variable(
            initial_value=tf.zeros(shape=[], dtype=tf.int64),
            trainable=False,
            name="global_step"
        )
        self.checkpoint_manager = None
        self.summary_file_writer = None

    @tf.function
    def increment_global_step(self):
        self.global_step.assign_add(
            delta=tf.ones(shape=[], dtype=tf.int64)
        )

    # train_and_eval.py
    def generator_loss_phase(self, mode, training):
        """Gets fake logits and loss for generator.

        Args:
            mode: str, what mode currently in: TRAIN or EVAL.
            training: bool, if model should be training.

        Returns:
            Fake logits of shape [batch_size, 1] and generator loss of shape
                [].
        """
        batch_size = (
            self.params["train_batch_size"]
            if mode == "TRAIN"
            else self.params["eval_batch_size"]
        )

        # Create random noise latent vector for each batch example.
        Z = tf.random.normal(
            shape=[batch_size, self.params["latent_size"]],
            mean=0.0,
            stddev=1.0,
            dtype=tf.float32
        )

        # Get generated image from generator network from gaussian noise.
        fake_images = self.network_models["generator"](
            inputs=Z, training=training
        )

        if self.params["write_summaries"] and mode == "TRAIN":
            # Add summaries for TensorBoard.
            with self.summary_file_writer.as_default():
                with tf.summary.record_if(
                condition=tf.equal(
                    x=tf.math.floormod(
                        x=self.global_step,
                        y=self.params["save_summary_steps"]
                    ), y=0
                )
                ):
                    tf.summary.image(
                        name="fake_images",
                        data=fake_images,
                        step=self.global_step,
                        max_outputs=5
                    )
                    self.summary_file_writer.flush()

        # Get fake logits from discriminator using generator's output image.
        fake_logits = self.network_models["discriminator"](
            inputs=fake_images, training=training
        )

        # Get generator total loss.
        generator_total_loss = (
            self.network_objects["generator"].get_generator_loss(
                global_batch_size=self.global_batch_size,
                fake_logits=fake_logits,
                global_step=self.global_step,
                summary_file_writer=self.summary_file_writer
            )
        )

        return fake_logits, generator_total_loss

    def discriminator_loss_phase(self, real_images, fake_logits, training):
        """Gets real logits and loss for discriminator.

        Args:
            real_images: tensor, real images of shape
                [batch_size, height * width * depth].
            fake_logits: tensor, discriminator logits of fake images of shape
                [batch_size, 1].
            training: bool, if in training mode.

        Returns:
            Real logits of shape [batch_size, 1] and discriminator loss of
                shape [].
        """
        # Get real logits from discriminator using real image.
        real_logits = self.network_models["discriminator"](
            inputs=real_images, training=training
        )

        # Get discriminator total loss.
        discriminator_total_loss = (
            self.network_objects["discriminator"].get_discriminator_loss(
                global_batch_size=self.global_batch_size,
                fake_logits=fake_logits,
                real_logits=real_logits,
                global_step=self.global_step,
                summary_file_writer=self.summary_file_writer
            )
        )

        return real_logits, discriminator_total_loss

    # train.py
    def get_variables_and_gradients(self, loss, gradient_tape, scope):
        """Gets variables and gradients from model wrt. loss.

        Args:
            loss: tensor, shape of [].
            gradient_tape: instance of `GradientTape`.
            scope: str, the name of the network of interest.

        Returns:
            Lists of network's variables and gradients.
        """
        # Get trainable variables.
        variables = self.network_models[scope].trainable_variables

        # Get gradients from gradient tape.
        gradients = gradient_tape.gradient(
            target=loss, sources=variables
        )

        # Clip gradients.
        if self.params["{}_clip_gradients".format(scope)]:
            gradients, _ = tf.clip_by_global_norm(
                t_list=gradients,
                clip_norm=params["{}_clip_gradients".format(scope)],
                name="{}_clip_by_global_norm_gradients".format(scope)
            )

        # Add variable names back in for identification.
        gradients = [
            tf.identity(
                input=g,
                name="{}_{}_gradients".format(scope, v.name[:-2])
            )
            if tf.is_tensor(x=g) else g
            for g, v in zip(gradients, variables)
        ]

        return variables, gradients

    def create_variable_and_gradient_histogram_summaries(
        self, variables, gradients, scope
    ):
        """Creates variable and gradient histogram summaries.

        Args:
            variables: list, network's trainable variables.
            gradients: list, gradients of network's trainable variables wrt.
                loss.
            scope: str, the name of the network of interest.
        """
        if self.params["write_summaries"]:
            # Add summaries for TensorBoard.
            with self.summary_file_writer.as_default():
                with tf.summary.record_if(
                    condition=tf.equal(
                        x=tf.math.floormod(
                            x=self.global_step,
                            y=self.params["save_summary_steps"]
                        ), y=0
                    )
                ):
                    for v, g in zip(variables, gradients):
                        tf.summary.histogram(
                            name="{}_variables/{}".format(
                                scope, v.name[:-2]
                            ),
                            data=v,
                            step=self.global_step
                        )
                        if tf.is_tensor(x=g):
                            tf.summary.histogram(
                                name="{}_gradients/{}".format(
                                    scope, v.name[:-2]
                                ),
                                data=g,
                                step=self.global_step
                            )
                    self.summary_file_writer.flush()

    def get_select_loss_variables_and_gradients(self, real_images, scope):
        """Gets selected network's loss, variables, and gradients.

        Args:
            real_images: tensor, real images of shape
                [batch_size, height * width * depth].
            scope: str, the name of the network of interest.

        Returns:
            Selected network's loss, variables, and gradients.
        """
        with tf.GradientTape() as gen_tape, tf.GradientTape() as dis_tape:
            # Get fake logits from generator.
            fake_logits, generator_loss = self.generator_loss_phase(
                mode="TRAIN", training=True
            )

            # Get discriminator loss.
            _, discriminator_loss = self.discriminator_loss_phase(
                real_images, fake_logits, training=True
            )

        # Create empty dicts to hold loss, variables, gradients.
        loss_dict = {}
        vars_dict = {}
        grads_dict = {}

        # Loop over generator and discriminator.
        for (loss, gradient_tape, scope_name) in zip(
            [generator_loss, discriminator_loss],
            [gen_tape, dis_tape],
            ["generator", "discriminator"]
        ):
            # Get variables and gradients from generator wrt. loss.
            variables, gradients = self.get_variables_and_gradients(
                loss, gradient_tape, scope_name
            )

            # Add loss, variables, and gradients to dictionaries.
            loss_dict[scope_name] = loss
            vars_dict[scope_name] = variables
            grads_dict[scope_name] = gradients

            # Create variable and gradient histogram summaries.
            self.create_variable_and_gradient_histogram_summaries(
                variables, gradients, scope_name
            )

        return loss_dict[scope], vars_dict[scope], grads_dict[scope]

    def train_network(self, variables, gradients, scope):
        """Trains network variables using gradients with optimizer.

        Args:
            variables: list, network's trainable variables.
            gradients: list, gradients of network's trainable variables wrt.
                loss.
            scope: str, the name of the network of interest.
        """
        # Zip together gradients and variables.
        grads_and_vars = zip(gradients, variables)

        # Applying gradients to variables using optimizer.
        self.optimizers[scope].apply_gradients(grads_and_vars=grads_and_vars)

    def train_discriminator(self, features):
        """Trains discriminator network.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Discriminator loss tensor.
        """
        # Extract real images from features dictionary.
        real_images = features["image"]

        # Get gradients for training by running inputs through networks.
        loss, variables, gradients = (
            self.get_select_loss_variables_and_gradients(
                real_images, scope="discriminator"
            )
        )

        # Train discriminator network.
        self.train_network(variables, gradients, scope="discriminator")

        return loss

    def train_generator(self, features):
        """Trains generator network.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Generator loss tensor.
        """
        # Extract real images from features dictionary.
        real_images = features["image"]

        # Get gradients for training by running inputs through networks.
        loss, variables, gradients = (
            self.get_select_loss_variables_and_gradients(
                real_images, scope="generator"
            )
        )

        # Train generator network.
        self.train_network(variables, gradients, scope="generator")

        return loss

    # instantiate_model.py
    def instantiate_network_objects(self):
        """Instantiates generator and discriminator with parameters.
        """
        # Instantiate generator.
        self.network_objects["generator"] = Generator(
            input_shape=(self.params["latent_size"]),
            kernel_regularizer=tf.keras.regularizers.l1_l2(
                l1=self.params["generator_l1_regularization_scale"],
                l2=self.params["generator_l2_regularization_scale"]
            ),
            bias_regularizer=None,
            name="generator",
            params=self.params
        )

        # Instantiate discriminator.
        self.network_objects["discriminator"] = Discriminator(
            input_shape=(
                self.params["height"],
                self.params["width"],
                self.params["depth"]
            ),
            kernel_regularizer=tf.keras.regularizers.l1_l2(
                l1=self.params["discriminator_l1_regularization_scale"],
                l2=self.params["discriminator_l2_regularization_scale"]
            ),
            bias_regularizer=None,
            name="discriminator",
            params=self.params
        )

    def instantiate_optimizer(self, scope):
        """Instantiates optimizer with parameters.

        Args:
            scope: str, the name of the network of interest.
        """
        # Create optimizer map.
        optimizers = {
            "Adadelta": tf.keras.optimizers.Adadelta,
            "Adagrad": tf.keras.optimizers.Adagrad,
            "Adam": tf.keras.optimizers.Adam,
            "Adamax": tf.keras.optimizers.Adamax,
            "Ftrl": tf.keras.optimizers.Ftrl,
            "Nadam": tf.keras.optimizers.Nadam,
            "RMSprop": tf.keras.optimizers.RMSprop,
            "SGD": tf.keras.optimizers.SGD
        }

        # Get optimizer and instantiate it.
        if self.params["{}_optimizer".format(scope)] == "Adam":
            optimizer = optimizers[self.params["{}_optimizer".format(scope)]](
                learning_rate=self.params["{}_learning_rate".format(scope)],
                beta_1=self.params["{}_adam_beta1".format(scope)],
                beta_2=self.params["{}_adam_beta2".format(scope)],
                epsilon=self.params["{}_adam_epsilon".format(scope)],
                name="{}_{}_optimizer".format(
                    scope, self.params["{}_optimizer".format(scope)].lower()
                )
            )
        else:
            optimizer = optimizers[self.params["{}_optimizer".format(scope)]](
                learning_rate=self.params["{}_learning_rate".format(scope)],
                name="{}_{}_optimizer".format(
                    scope, self.params["{}_optimizer".format(scope)].lower()
                )
            )

        self.optimizers[scope] = optimizer

    def instantiate_model_objects(self):
        """Instantiate model network objects, network models, and optimizers.
        """
        # Instantiate generator and discriminator objects.
        self.instantiate_network_objects()

        # Get generator and discriminator `Model`s.
        self.network_models["generator"] = (
            self.network_objects["generator"].get_model()
        )

        self.network_models["discriminator"] = (
            self.network_objects["discriminator"].get_model()
        )

        # Instantiate generator optimizer.
        self.instantiate_optimizer(scope="generator")

        # Instantiate discriminator optimizer.
        self.instantiate_optimizer(scope="discriminator")

    # model.py
    def get_train_eval_datasets(self, num_replicas):
        """Gets train and eval datasets.

        Args:
            num_replicas: int, number of device replicas.

        Returns:
            Train and eval datasets.
        """
        train_dataset = read_dataset(
            filename=self.params["train_file_pattern"],
            batch_size=self.params["train_batch_size"] * num_replicas,
            params=self.params,
            training=True
        )()

        eval_dataset = read_dataset(
            filename=self.params["eval_file_pattern"],
            batch_size=self.params["eval_batch_size"] * num_replicas,
            params=self.params,
            training=False
        )()
        if self.params["eval_steps"]:
            eval_dataset = eval_dataset.take(count=self.params["eval_steps"])

        return train_dataset, eval_dataset

    def create_checkpoint_machinery(self):
        """Creates checkpoint machinery needed to save & restore checkpoints.
        """
        # Create checkpoint instance.
        checkpoint_dir = os.path.join(
            self.params["output_dir"], "checkpoints"
        )
        checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
        checkpoint = tf.train.Checkpoint(
            generator_model=self.network_models["generator"],
            discriminator_model=self.network_models["discriminator"],
            generator_optimizer=self.optimizers["generator"],
            discriminator_optimizer=self.optimizers["discriminator"]
        )

        # Create checkpoint manager.
        self.checkpoint_manager = tf.train.CheckpointManager(
            checkpoint=checkpoint,
            directory=checkpoint_dir,
            max_to_keep=self.params["keep_checkpoint_max"],
            step_counter=self.global_step,
            checkpoint_interval=self.params["save_checkpoints_steps"]
        )

        # Restore any prior checkpoints.
        status = checkpoint.restore(
            save_path=self.checkpoint_manager.latest_checkpoint
        )

    def distributed_eager_discriminator_train_step(self, features):
        """Perform one distributed, eager discriminator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        if self.params["tf_version"] > 2.1:
            run_function = self.strategy.run
        else:
            run_function = self.strategy.experimental_run_v2

        per_replica_losses = run_function(
            fn=self.train_discriminator, kwargs={"features": features}
        )

        return self.strategy.reduce(
            reduce_op=tf.distribute.ReduceOp.SUM,
            value=per_replica_losses,
            axis=None
        )

    def non_distributed_eager_discriminator_train_step(self, features):
        """Perform one non-distributed, eager discriminator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        return self.train_discriminator(features=features)

    @tf.function
    def distributed_graph_discriminator_train_step(self, features):
        """Perform one distributed, graph discriminator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        if self.params["tf_version"] > 2.1:
            run_function = self.strategy.run
        else:
            run_function = self.strategy.experimental_run_v2

        per_replica_losses = run_function(
            fn=self.train_discriminator, kwargs={"features": features}
        )

        return self.strategy.reduce(
            reduce_op=tf.distribute.ReduceOp.SUM,
            value=per_replica_losses,
            axis=None
        )

    @tf.function
    def non_distributed_graph_discriminator_train_step(self, features):
        """Perform one non-distributed, graph discriminator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        return self.train_discriminator(features=features)

    def distributed_eager_generator_train_step(self, features):
        """Perform one distributed, eager generator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        if self.params["tf_version"] > 2.1:
            run_function = self.strategy.run
        else:
            run_function = self.strategy.experimental_run_v2

        per_replica_losses = run_function(
            fn=self.train_generator, kwargs={"features": features}
        )

        return self.strategy.reduce(
            reduce_op=tf.distribute.ReduceOp.SUM,
            value=per_replica_losses,
            axis=None
        )

    def non_distributed_eager_generator_train_step(self, features):
        """Perform one non-distributed, eager generator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        return self.train_generator(features=features)

    @tf.function
    def distributed_graph_generator_train_step(self, features):
        """Perform one distributed, graph generator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        if self.params["tf_version"] > 2.1:
            run_function = self.strategy.run
        else:
            run_function = self.strategy.experimental_run_v2

        per_replica_losses = run_function(
            fn=self.train_generator, kwargs={"features": features}
        )

        return self.strategy.reduce(
            reduce_op=tf.distribute.ReduceOp.SUM,
            value=per_replica_losses,
            axis=None
        )

    @tf.function
    def non_distributed_graph_generator_train_step(self, features):
        """Perform one non-distributed, graph generator train step.

        Args:
            features: dict, feature tensors from input function.

        Returns:
            Reduced loss tensor for chosen network across replicas.
        """
        return self.train_generator(features=features)

    def log_step_loss(self, epoch, epoch_step, loss):
        """Logs step information and loss.

        Args:
            epoch: int, current iteration fully through the dataset.
            epoch_step: int, number of batches through epoch.
            loss: float, the loss of the model at the current step.
        """
        if self.global_step % self.params["log_step_count_steps"] == 0:
            print(
                "epoch = {}, global_step = {}, epoch_step = {}, loss = {}".format(
                    epoch, self.global_step, epoch_step, loss
                )
            )

    def training_loop(self, steps_per_epoch, train_dataset_iter):
        """Logs step information and loss.

        Args:
            steps_per_epoch: int, number of steps/batches to take each epoch.
            train_dataset_iter: iterator, training dataset iterator.
        """
        # Get correct train function based on parameters.
        if self.strategy:
            if self.params["use_graph_mode"]:
                discriminator_train_step_fn = (
                    self.distributed_graph_discriminator_train_step
                )
                generator_train_step_fn = (
                    self.distributed_graph_generator_train_step
                )
            else:
                discriminator_train_step_fn = (
                    self.distributed_eager_discriminator_train_step
                )
                generator_train_step_fn = (
                    self.distributed_eager_generator_train_step
                )
        else:
            if self.params["use_graph_mode"]:
                discriminator_train_step_fn = (
                    self.non_distributed_graph_discriminator_train_step
                )
                generator_train_step_fn = (
                    self.non_distributed_graph_generator_train_step
                )
            else:
                discriminator_train_step_fn = (
                    self.non_distributed_eager_discriminator_train_step
                )
                generator_train_step_fn = (
                    self.non_distributed_eager_generator_train_step
                )

        for epoch in range(self.params["num_epochs"]):
            for epoch_step in range(steps_per_epoch):
                # Train model on batch of features and get loss.
                features, labels = next(train_dataset_iter)

                # Determine if it is time to train generator or discriminator.
                cycle_step = self.global_step % (
                    self.params["discriminator_train_steps"] + self.params["generator_train_steps"]
                )

                # Conditionally choose to train generator or discriminator subgraph.
                if cycle_step < self.params["discriminator_train_steps"]:
                    loss = discriminator_train_step_fn(features=features)
                else:
                    loss = generator_train_step_fn(features=features)

                # Log step information and loss.
                self.log_step_loss(epoch, epoch_step, loss)

                # Checkpoint model every save_checkpoints_steps steps.
                self.checkpoint_manager.save(
                    checkpoint_number=self.global_step, check_interval=True
                )

                # Increment global step.
                self.increment_global_step()

    def training_loop_end_save_model(self):
        """Saving model when training loop ends.
        """
        # Write final checkpoint.
        self.checkpoint_manager.save(
            checkpoint_number=self.global_step, check_interval=False
        )

        # Export SavedModel for serving.
        export_path = os.path.join(
            self.params["output_dir"],
            "export",
            datetime.datetime.now().strftime("%Y%m%d%H%M%S")
        )

        # Signature will be serving_default.
        tf.saved_model.save(
            obj=self.network_models["generator"], export_dir=export_path
        )

    def train_block(self, train_dataset, eval_dataset):
        """Training block setups training, then loops through datasets.

        Args:
            train_dataset: instance of `Dataset` for training data.
            eval_dataset: instance of `Dataset` for evaluation data.
        """
        # Create iterators of datasets.
        train_dataset_iter = iter(train_dataset)
        eval_dataset_iter = iter(eval_dataset)

        steps_per_epoch = (
            self.params["train_dataset_length"] // self.global_batch_size
        )

        # Instantiate model objects.
        self.instantiate_model_objects()

        # Create checkpoint machinery to save/restore checkpoints.
        self.create_checkpoint_machinery()

        # Create summary file writer.
        self.summary_file_writer = tf.summary.create_file_writer(
            logdir=os.path.join(self.params["output_dir"], "summaries"),
            name="summary_file_writer"
        )

        # Run training loop.
        self.training_loop(steps_per_epoch, train_dataset_iter)

        # Save model at end of training loop.
        self.training_loop_end_save_model()

    def train_and_evaluate(self):
        """Trains and evaluates Keras model.

        Args:
            args: dict, user passed parameters.

        Returns:
            Generator's `Model` object for in-memory predictions.
        """
        if self.params["distribution_strategy"]:
            # If the list of devices is not specified in the
            # Strategy constructor, it will be auto-detected.
            if self.params["distribution_strategy"] == "Mirrored":
                self.strategy = tf.distribute.MirroredStrategy()
            print(
                "Number of devices = {}".format(
                    self.strategy.num_replicas_in_sync
                )
            )

            # Set global batch size for training.
            self.global_batch_size = (
                self.params["train_batch_size"] * self.strategy.num_replicas_in_sync
            )

            # Get input datasets. Batch size is split evenly between replicas.
            train_dataset, eval_dataset = self.get_train_eval_datasets(
                num_replicas=self.strategy.num_replicas_in_sync
            )

            with self.strategy.scope():
                # Create distributed datasets.
                train_dist_dataset = (
                    self.strategy.experimental_distribute_dataset(
                        dataset=train_dataset
                    )
                )
                eval_dist_dataset = (
                    self.strategy.experimental_distribute_dataset(
                        dataset=eval_dataset
                    )
                )

                # Training block setups training, then loops through datasets.
                self.train_block(
                    train_dataset=train_dist_dataset,
                    eval_dataset=eval_dist_dataset
                )
        else:
            # Set global batch size for training.
            self.global_batch_size = self.params["train_batch_size"]

            # Get input datasets.
            train_dataset, eval_dataset = self.get_train_eval_datasets(
                num_replicas=1
            )

            # Training block setups training, then loops through datasets.
            self.train_block(
                train_dataset=train_dataset, eval_dataset=eval_dataset
            )

# %% [markdown]
# ## Run model

# %%
os.environ["OUTPUT_DIR"] = arguments["output_dir"]

# %%
# %%bash
# gsutil -m rm -rf ${OUTPUT_DIR}
# Out:
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/#1596180840359759...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/#1596180844720411...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/checkpoint#1596180883227570...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.data-00000-of-00002#1596180848102829...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.data-00001-of-00002#1596180847818989...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.index#1596180848327580...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-1875.data-00000-of-00002#1596180881926991...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-1875.data-00001-of-00002#1596180881686037...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-1875.index#1596180882154363...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/#1596180885326712...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/#1596180885549735...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/assets/#1596180889767144...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/saved_model.pb#1596180890117399...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/variables/#1596180885778798...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/variables/variables.data-00000-of-00002#1596180888851955...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/variables/variables.index#1596180889091235...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/summaries/#1596180840579903...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/summaries/events.out.tfevents.1596180840.tensorflow-2-2-20200707-090436.16144.1827.v2#1596180840765050...
# Removing gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731073443/variables/variables.data-00001-of-00002#1596180888672218...
# / [19/19 objects] 100% Done
# Operation completed over 19 objects.

# %%
train_and_evaluate_loop = TrainAndEvaluateLoop(params=arguments)

# %%
train_and_evaluate_loop.train_and_evaluate()
# Out:
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=0>, epoch_step = 0, loss = 1.3686797618865967
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=100>, epoch_step = 100, loss = 0.797965943813324
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=200>, epoch_step = 200, loss = 1.1874349117279053
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=300>, epoch_step = 300, loss = 1.1481997966766357
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=400>, epoch_step = 400, loss = 0.9984132051467896
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=500>, epoch_step = 500, loss = 1.0843909978866577
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=600>, epoch_step = 600, loss = 1.0803972482681274
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=700>, epoch_step = 700, loss = 1.1786404848098755
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=800>, epoch_step = 800, loss = 1.0488468408584595
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=900>, epoch_step = 900, loss = 1.0959492921829224
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1000>, epoch_step = 1000, loss = 0.9802986979484558
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1100>, epoch_step = 1100, loss = 0.9554206728935242
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1200>, epoch_step = 1200, loss = 1.0373566150665283
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1300>, epoch_step = 1300, loss = 1.0145344734191895
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1400>, epoch_step = 1400, loss = 1.0593088865280151
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1500>, epoch_step = 1500, loss = 0.9692482948303223
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1600>, epoch_step = 1600, loss = 1.0479979515075684
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1700>, epoch_step = 1700, loss = 1.0080840587615967
# epoch = 0, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1800>, epoch_step = 1800, loss = 1.0486817359924316
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=1900>, epoch_step = 25, loss = 1.0750796794891357
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2000>, epoch_step = 125, loss = 1.1150100231170654
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2100>, epoch_step = 225, loss = 1.000424861907959
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2200>, epoch_step = 325, loss = 1.0489712953567505
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2300>, epoch_step = 425, loss = 1.0173161029815674
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2400>, epoch_step = 525, loss = 1.0499489307403564
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2500>, epoch_step = 625, loss = 0.9970127940177917
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2600>, epoch_step = 725, loss = 1.0621916055679321
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2700>, epoch_step = 825, loss = 1.0397803783416748
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2800>, epoch_step = 925, loss = 1.0834604501724243
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=2900>, epoch_step = 1025, loss = 1.060100793838501
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3000>, epoch_step = 1125, loss = 1.0911343097686768
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3100>, epoch_step = 1225, loss = 1.0587636232376099
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3200>, epoch_step = 1325, loss = 1.1142884492874146
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3300>, epoch_step = 1425, loss = 1.0974938869476318
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3400>, epoch_step = 1525, loss = 1.1065186262130737
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3500>, epoch_step = 1625, loss = 1.0866949558258057
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3600>, epoch_step = 1725, loss = 1.0779707431793213
# epoch = 1, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3700>, epoch_step = 1825, loss = 1.1273168325424194
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3800>, epoch_step = 50, loss = 1.0531061887741089
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3900>, epoch_step = 150, loss = 1.0484896898269653
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4000>, epoch_step = 250, loss = 1.1388424634933472
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4100>, epoch_step = 350, loss = 1.1874394416809082
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4200>, epoch_step = 450, loss = 1.1002097129821777
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4300>, epoch_step = 550, loss = 1.0704641342163086
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4400>, epoch_step = 650, loss = 1.152184247970581
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4500>, epoch_step = 750, loss = 1.0091779232025146
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4600>, epoch_step = 850, loss = 1.03148353099823
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4700>, epoch_step = 950, loss = 1.1005394458770752
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4800>, epoch_step = 1050, loss = 1.141802430152893
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=4900>, epoch_step = 1150, loss = 1.002625584602356
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5000>, epoch_step = 1250, loss = 1.0893054008483887
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5100>, epoch_step = 1350, loss = 1.1192909479141235
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5200>, epoch_step = 1450, loss = 1.0272027254104614
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5300>, epoch_step = 1550, loss = 1.1281836032867432
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5400>, epoch_step = 1650, loss = 1.0771431922912598
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5500>, epoch_step = 1750, loss = 1.126947045326233
# epoch = 2, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5600>, epoch_step = 1850, loss = 1.047993779182434
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5700>, epoch_step = 75, loss = 0.9913408756256104
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5800>, epoch_step = 175, loss = 1.128551721572876
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=5900>, epoch_step = 275, loss = 1.0542091131210327
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6000>, epoch_step = 375, loss = 1.0695157051086426
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6100>, epoch_step = 475, loss = 1.091393232345581
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6200>, epoch_step = 575, loss = 1.0471099615097046
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6300>, epoch_step = 675, loss = 1.0262550115585327
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6400>, epoch_step = 775, loss = 1.097717523574829
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6500>, epoch_step = 875, loss = 1.0368897914886475
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6600>, epoch_step = 975, loss = 1.168090581893921
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6700>, epoch_step = 1075, loss = 1.016680359840393
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6800>, epoch_step = 1175, loss = 1.0192272663116455
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=6900>, epoch_step = 1275, loss = 1.0088162422180176
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7000>, epoch_step = 1375, loss = 1.1246296167373657
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7100>, epoch_step = 1475, loss = 1.0802879333496094
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7200>, epoch_step = 1575, loss = 1.090728998184204
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7300>, epoch_step = 1675, loss = 1.074816346168518
# epoch = 3, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7400>, epoch_step = 1775, loss = 1.080359697341919
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7500>, epoch_step = 0, loss = 1.0703420639038086
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7600>, epoch_step = 100, loss = 1.0191681385040283
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7700>, epoch_step = 200, loss = 1.0015864372253418
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7800>, epoch_step = 300, loss = 0.9912096261978149
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=7900>, epoch_step = 400, loss = 1.098125696182251
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8000>, epoch_step = 500, loss = 1.0520763397216797
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8100>, epoch_step = 600, loss = 1.068412184715271
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8200>, epoch_step = 700, loss = 1.083031415939331
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8300>, epoch_step = 800, loss = 1.0396455526351929
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8400>, epoch_step = 900, loss = 0.9827038049697876
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8500>, epoch_step = 1000, loss = 1.0674870014190674
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8600>, epoch_step = 1100, loss = 1.0678398609161377
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8700>, epoch_step = 1200, loss = 1.0336666107177734
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8800>, epoch_step = 1300, loss = 1.0794754028320312
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=8900>, epoch_step = 1400, loss = 1.0591204166412354
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9000>, epoch_step = 1500, loss = 1.0604968070983887
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9100>, epoch_step = 1600, loss = 1.064400315284729
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9200>, epoch_step = 1700, loss = 1.0742838382720947
# epoch = 4, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9300>, epoch_step = 1800, loss = 1.053032398223877
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9400>, epoch_step = 25, loss = 1.057279109954834
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9500>, epoch_step = 125, loss = 1.0139089822769165
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9600>, epoch_step = 225, loss = 1.0864076614379883
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9700>, epoch_step = 325, loss = 1.03684663772583
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9800>, epoch_step = 425, loss = 1.0853958129882812
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=9900>, epoch_step = 525, loss = 1.030202031135559
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10000>, epoch_step = 625, loss = 1.0050420761108398
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10100>, epoch_step = 725, loss = 1.0683386325836182
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10200>, epoch_step = 825, loss = 1.051741361618042
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10300>, epoch_step = 925, loss = 1.0863007307052612
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10400>, epoch_step = 1025, loss = 1.0644640922546387
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10500>, epoch_step = 1125, loss = 1.071468472480774
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10600>, epoch_step = 1225, loss = 1.11227548122406
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10700>, epoch_step = 1325, loss = 0.9939152598381042
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10800>, epoch_step = 1425, loss = 1.0790467262268066
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=10900>, epoch_step = 1525, loss = 1.0085893869400024
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11000>, epoch_step = 1625, loss = 1.0274217128753662
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11100>, epoch_step = 1725, loss = 1.1025117635726929
# epoch = 5, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11200>, epoch_step = 1825, loss = 1.0188918113708496
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11300>, epoch_step = 50, loss = 0.9866423606872559
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11400>, epoch_step = 150, loss = 1.055842399597168
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11500>, epoch_step = 250, loss = 1.0606889724731445
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11600>, epoch_step = 350, loss = 1.0084530115127563
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11700>, epoch_step = 450, loss = 1.1150418519973755
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11800>, epoch_step = 550, loss = 1.0151649713516235
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=11900>, epoch_step = 650, loss = 1.0670322179794312
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12000>, epoch_step = 750, loss = 1.06856369972229
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12100>, epoch_step = 850, loss = 0.9820349812507629
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12200>, epoch_step = 950, loss = 1.041794776916504
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12300>, epoch_step = 1050, loss = 1.0741140842437744
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12400>, epoch_step = 1150, loss = 1.099021077156067
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12500>, epoch_step = 1250, loss = 1.000538945198059
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12600>, epoch_step = 1350, loss = 1.0773829221725464
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12700>, epoch_step = 1450, loss = 1.0202441215515137
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12800>, epoch_step = 1550, loss = 1.0279037952423096
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=12900>, epoch_step = 1650, loss = 1.010711908340454
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13000>, epoch_step = 1750, loss = 1.0519593954086304
# epoch = 6, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13100>, epoch_step = 1850, loss = 1.044735312461853
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13200>, epoch_step = 75, loss = 1.0771950483322144
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13300>, epoch_step = 175, loss = 1.0251166820526123
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13400>, epoch_step = 275, loss = 1.0477937459945679
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13500>, epoch_step = 375, loss = 0.9227644205093384
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13600>, epoch_step = 475, loss = 1.0283502340316772
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13700>, epoch_step = 575, loss = 1.044630765914917
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13800>, epoch_step = 675, loss = 0.9851995706558228
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=13900>, epoch_step = 775, loss = 1.0427552461624146
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14000>, epoch_step = 875, loss = 1.0368417501449585
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14100>, epoch_step = 975, loss = 1.1177101135253906
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14200>, epoch_step = 1075, loss = 1.0447242259979248
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14300>, epoch_step = 1175, loss = 1.0376362800598145
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14400>, epoch_step = 1275, loss = 1.0075726509094238
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14500>, epoch_step = 1375, loss = 0.8960468769073486
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14600>, epoch_step = 1475, loss = 0.9994014501571655
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14700>, epoch_step = 1575, loss = 1.0587302446365356
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14800>, epoch_step = 1675, loss = 0.963850736618042
# epoch = 7, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=14900>, epoch_step = 1775, loss = 1.0187898874282837
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15000>, epoch_step = 0, loss = 1.000037431716919
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15100>, epoch_step = 100, loss = 1.058149814605713
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15200>, epoch_step = 200, loss = 1.080507516860962
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15300>, epoch_step = 300, loss = 1.006605625152588
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15400>, epoch_step = 400, loss = 1.1033920049667358
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15500>, epoch_step = 500, loss = 1.00914466381073
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15600>, epoch_step = 600, loss = 1.058441162109375
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15700>, epoch_step = 700, loss = 1.0377960205078125
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15800>, epoch_step = 800, loss = 1.0432214736938477
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=15900>, epoch_step = 900, loss = 0.9937950968742371
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16000>, epoch_step = 1000, loss = 1.0787734985351562
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16100>, epoch_step = 1100, loss = 0.9812538623809814
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16200>, epoch_step = 1200, loss = 0.9978559613227844
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16300>, epoch_step = 1300, loss = 1.0765503644943237
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16400>, epoch_step = 1400, loss = 1.1217763423919678
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16500>, epoch_step = 1500, loss = 1.0388656854629517
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16600>, epoch_step = 1600, loss = 1.0359779596328735
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16700>, epoch_step = 1700, loss = 0.9777679443359375
# epoch = 8, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16800>, epoch_step = 1800, loss = 1.0353671312332153
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=16900>, epoch_step = 25, loss = 1.0200387239456177
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17000>, epoch_step = 125, loss = 1.0133724212646484
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17100>, epoch_step = 225, loss = 0.9891456365585327
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17200>, epoch_step = 325, loss = 0.9966701865196228
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17300>, epoch_step = 425, loss = 1.0016037225723267
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17400>, epoch_step = 525, loss = 0.9450359344482422
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17500>, epoch_step = 625, loss = 0.9994310736656189
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17600>, epoch_step = 725, loss = 1.1008151769638062
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17700>, epoch_step = 825, loss = 1.0217852592468262
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17800>, epoch_step = 925, loss = 0.9508246779441833
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=17900>, epoch_step = 1025, loss = 0.9880687594413757
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18000>, epoch_step = 1125, loss = 1.003358244895935
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18100>, epoch_step = 1225, loss = 1.0129268169403076
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18200>, epoch_step = 1325, loss = 1.0182106494903564
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18300>, epoch_step = 1425, loss = 0.9736305475234985
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18400>, epoch_step = 1525, loss = 0.9948497414588928
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18500>, epoch_step = 1625, loss = 1.0225852727890015
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18600>, epoch_step = 1725, loss = 1.0427886247634888
# epoch = 9, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18700>, epoch_step = 1825, loss = 1.0120856761932373
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18800>, epoch_step = 50, loss = 1.0269420146942139
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=18900>, epoch_step = 150, loss = 0.9504156112670898
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19000>, epoch_step = 250, loss = 1.0412518978118896
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19100>, epoch_step = 350, loss = 1.0485609769821167
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19200>, epoch_step = 450, loss = 1.0401452779769897
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19300>, epoch_step = 550, loss = 0.9822171330451965
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19400>, epoch_step = 650, loss = 1.0309233665466309
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19500>, epoch_step = 750, loss = 0.9720634818077087
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19600>, epoch_step = 850, loss = 0.9499694108963013
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19700>, epoch_step = 950, loss = 1.0043994188308716
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19800>, epoch_step = 1050, loss = 0.9819425344467163
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=19900>, epoch_step = 1150, loss = 0.9975641369819641
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20000>, epoch_step = 1250, loss = 1.0201691389083862
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20100>, epoch_step = 1350, loss = 0.9859402775764465
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20200>, epoch_step = 1450, loss = 1.0469826459884644
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20300>, epoch_step = 1550, loss = 1.0028854608535767
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20400>, epoch_step = 1650, loss = 0.959941029548645
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20500>, epoch_step = 1750, loss = 1.0915361642837524
# epoch = 10, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20600>, epoch_step = 1850, loss = 1.0381090641021729
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20700>, epoch_step = 75, loss = 1.012046456336975
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20800>, epoch_step = 175, loss = 1.0596696138381958
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=20900>, epoch_step = 275, loss = 1.0230398178100586
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21000>, epoch_step = 375, loss = 1.0305204391479492
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21100>, epoch_step = 475, loss = 1.0232751369476318
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21200>, epoch_step = 575, loss = 0.98893803358078
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21300>, epoch_step = 675, loss = 1.0121568441390991
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21400>, epoch_step = 775, loss = 1.1404911279678345
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21500>, epoch_step = 875, loss = 1.0325658321380615
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21600>, epoch_step = 975, loss = 1.0182876586914062
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21700>, epoch_step = 1075, loss = 1.071789264678955
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21800>, epoch_step = 1175, loss = 1.0096980333328247
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=21900>, epoch_step = 1275, loss = 0.9497854113578796
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22000>, epoch_step = 1375, loss = 1.0352636575698853
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22100>, epoch_step = 1475, loss = 1.0478284358978271
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22200>, epoch_step = 1575, loss = 1.094877004623413
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22300>, epoch_step = 1675, loss = 1.0275105237960815
# epoch = 11, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22400>, epoch_step = 1775, loss = 1.0172154903411865
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22500>, epoch_step = 0, loss = 0.9667149782180786
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22600>, epoch_step = 100, loss = 1.0026626586914062
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22700>, epoch_step = 200, loss = 0.9939501285552979
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22800>, epoch_step = 300, loss = 1.0082406997680664
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=22900>, epoch_step = 400, loss = 1.0155340433120728
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23000>, epoch_step = 500, loss = 0.9487751722335815
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23100>, epoch_step = 600, loss = 0.9671031832695007
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23200>, epoch_step = 700, loss = 0.9678598642349243
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23300>, epoch_step = 800, loss = 0.9832061529159546
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23400>, epoch_step = 900, loss = 1.003418207168579
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23500>, epoch_step = 1000, loss = 1.049531102180481
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23600>, epoch_step = 1100, loss = 0.9543860554695129
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23700>, epoch_step = 1200, loss = 1.059983491897583
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23800>, epoch_step = 1300, loss = 1.0096805095672607
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=23900>, epoch_step = 1400, loss = 1.0027681589126587
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24000>, epoch_step = 1500, loss = 1.0725221633911133
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24100>, epoch_step = 1600, loss = 0.9738402366638184
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24200>, epoch_step = 1700, loss = 1.0710082054138184
# epoch = 12, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24300>, epoch_step = 1800, loss = 0.9946311712265015
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24400>, epoch_step = 25, loss = 1.0356181859970093
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24500>, epoch_step = 125, loss = 0.9917579293251038
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24600>, epoch_step = 225, loss = 1.0348777770996094
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24700>, epoch_step = 325, loss = 1.0532197952270508
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24800>, epoch_step = 425, loss = 1.010291576385498
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=24900>, epoch_step = 525, loss = 1.0910375118255615
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25000>, epoch_step = 625, loss = 1.033949851989746
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25100>, epoch_step = 725, loss = 1.0192584991455078
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25200>, epoch_step = 825, loss = 0.9462662935256958
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25300>, epoch_step = 925, loss = 1.0135927200317383
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25400>, epoch_step = 1025, loss = 0.9000205397605896
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25500>, epoch_step = 1125, loss = 0.9987108707427979
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25600>, epoch_step = 1225, loss = 0.9293019771575928
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25700>, epoch_step = 1325, loss = 1.0039924383163452
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25800>, epoch_step = 1425, loss = 1.0042709112167358
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=25900>, epoch_step = 1525, loss = 0.9732339978218079
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26000>, epoch_step = 1625, loss = 1.0813050270080566
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26100>, epoch_step = 1725, loss = 0.972476601600647
# epoch = 13, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26200>, epoch_step = 1825, loss = 1.021064281463623
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26300>, epoch_step = 50, loss = 0.9930320978164673
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26400>, epoch_step = 150, loss = 1.0121610164642334
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26500>, epoch_step = 250, loss = 1.0700780153274536
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26600>, epoch_step = 350, loss = 1.0502328872680664
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26700>, epoch_step = 450, loss = 1.0708308219909668
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26800>, epoch_step = 550, loss = 0.991637647151947
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=26900>, epoch_step = 650, loss = 1.0378918647766113
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27000>, epoch_step = 750, loss = 1.0795516967773438
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27100>, epoch_step = 850, loss = 0.9877428412437439
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27200>, epoch_step = 950, loss = 0.9666991233825684
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27300>, epoch_step = 1050, loss = 1.0655262470245361
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27400>, epoch_step = 1150, loss = 1.085906982421875
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27500>, epoch_step = 1250, loss = 0.9936900734901428
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27600>, epoch_step = 1350, loss = 0.9169102311134338
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27700>, epoch_step = 1450, loss = 0.9216238260269165
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27800>, epoch_step = 1550, loss = 1.1037240028381348
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=27900>, epoch_step = 1650, loss = 0.9981792569160461
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28000>, epoch_step = 1750, loss = 0.982956051826477
# epoch = 14, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28100>, epoch_step = 1850, loss = 0.9922923445701599
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28200>, epoch_step = 75, loss = 0.9834672212600708
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28300>, epoch_step = 175, loss = 0.9893862009048462
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28400>, epoch_step = 275, loss = 0.9658560752868652
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28500>, epoch_step = 375, loss = 1.0028762817382812
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28600>, epoch_step = 475, loss = 0.9923645853996277
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28700>, epoch_step = 575, loss = 0.997878909111023
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28800>, epoch_step = 675, loss = 1.083292007446289
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=28900>, epoch_step = 775, loss = 1.033329725265503
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29000>, epoch_step = 875, loss = 0.9948768615722656
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29100>, epoch_step = 975, loss = 1.0209907293319702
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29200>, epoch_step = 1075, loss = 1.0341464281082153
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29300>, epoch_step = 1175, loss = 1.0939984321594238
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29400>, epoch_step = 1275, loss = 1.047518014907837
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29500>, epoch_step = 1375, loss = 1.0020124912261963
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29600>, epoch_step = 1475, loss = 1.0410228967666626
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29700>, epoch_step = 1575, loss = 0.93161541223526
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29800>, epoch_step = 1675, loss = 1.0599706172943115
# epoch = 15, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=29900>, epoch_step = 1775, loss = 0.9725664854049683
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30000>, epoch_step = 0, loss = 1.0150569677352905
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30100>, epoch_step = 100, loss = 0.9985988140106201
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30200>, epoch_step = 200, loss = 1.0259020328521729
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30300>, epoch_step = 300, loss = 1.0092599391937256
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30400>, epoch_step = 400, loss = 1.0378153324127197
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30500>, epoch_step = 500, loss = 0.9671956300735474
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30600>, epoch_step = 600, loss = 1.082613468170166
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30700>, epoch_step = 700, loss = 0.9815390110015869
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30800>, epoch_step = 800, loss = 1.0066883563995361
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=30900>, epoch_step = 900, loss = 1.0335478782653809
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31000>, epoch_step = 1000, loss = 1.0161139965057373
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31100>, epoch_step = 1100, loss = 1.0584628582000732
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31200>, epoch_step = 1200, loss = 1.0074501037597656
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31300>, epoch_step = 1300, loss = 1.0256333351135254
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31400>, epoch_step = 1400, loss = 1.016195297241211
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31500>, epoch_step = 1500, loss = 1.0518982410430908
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31600>, epoch_step = 1600, loss = 1.0134892463684082
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31700>, epoch_step = 1700, loss = 1.0127818584442139
# epoch = 16, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31800>, epoch_step = 1800, loss = 0.9809101223945618
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=31900>, epoch_step = 25, loss = 1.023244023323059
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32000>, epoch_step = 125, loss = 1.0060646533966064
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32100>, epoch_step = 225, loss = 0.9878061413764954
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32200>, epoch_step = 325, loss = 0.9994323253631592
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32300>, epoch_step = 425, loss = 0.9704684019088745
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32400>, epoch_step = 525, loss = 1.0272932052612305
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32500>, epoch_step = 625, loss = 1.0090986490249634
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32600>, epoch_step = 725, loss = 0.9959521293640137
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32700>, epoch_step = 825, loss = 1.057694911956787
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32800>, epoch_step = 925, loss = 0.9619767665863037
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=32900>, epoch_step = 1025, loss = 1.0193935632705688
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33000>, epoch_step = 1125, loss = 1.0905406475067139
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33100>, epoch_step = 1225, loss = 1.019411325454712
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33200>, epoch_step = 1325, loss = 1.0389167070388794
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33300>, epoch_step = 1425, loss = 1.0189025402069092
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33400>, epoch_step = 1525, loss = 1.0168383121490479
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33500>, epoch_step = 1625, loss = 0.9802624583244324
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33600>, epoch_step = 1725, loss = 0.9323087334632874
# epoch = 17, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33700>, epoch_step = 1825, loss = 0.9422490000724792
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33800>, epoch_step = 50, loss = 0.9496926069259644
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=33900>, epoch_step = 150, loss = 1.0709128379821777
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34000>, epoch_step = 250, loss = 1.0123234987258911
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34100>, epoch_step = 350, loss = 1.00631844997406
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34200>, epoch_step = 450, loss = 0.9718869924545288
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34300>, epoch_step = 550, loss = 1.0420563220977783
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34400>, epoch_step = 650, loss = 0.9961716532707214
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34500>, epoch_step = 750, loss = 0.9722055792808533
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34600>, epoch_step = 850, loss = 1.027530312538147
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34700>, epoch_step = 950, loss = 0.9828169345855713
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34800>, epoch_step = 1050, loss = 1.0501292943954468
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=34900>, epoch_step = 1150, loss = 1.077505111694336
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35000>, epoch_step = 1250, loss = 0.9773527383804321
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35100>, epoch_step = 1350, loss = 1.026376724243164
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35200>, epoch_step = 1450, loss = 1.046177864074707
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35300>, epoch_step = 1550, loss = 0.9731717705726624
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35400>, epoch_step = 1650, loss = 0.9360742568969727
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35500>, epoch_step = 1750, loss = 0.9991533756256104
# epoch = 18, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=35600>, epoch_step = 1850, loss = 0.9452252388000488
# ...
# epoch = 23, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=44900>, epoch_step = 1775, loss = 0.9679927825927734
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45000>, epoch_step = 0, loss = 1.0340335369110107
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45100>, epoch_step = 100, loss = 1.0027371644973755
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45200>, epoch_step = 200, loss = 0.9799987077713013
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45300>, epoch_step = 300, loss = 0.9920635223388672
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45400>, epoch_step = 400, loss = 1.0880757570266724
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45500>, epoch_step = 500, loss = 0.9526467323303223
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45600>, epoch_step = 600, loss = 0.9931877851486206
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45700>, epoch_step = 700, loss = 0.9739331007003784
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45800>, epoch_step = 800, loss = 0.998046875
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=45900>, epoch_step = 900, loss = 1.0425493717193604
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46000>, epoch_step = 1000, loss = 1.026540994644165
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46100>, epoch_step = 1100, loss = 0.987876296043396
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46200>, epoch_step = 1200, loss = 1.0511729717254639
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46300>, epoch_step = 1300, loss = 1.0580172538757324
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46400>, epoch_step = 1400, loss = 0.9539873003959656
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46500>, epoch_step = 1500, loss = 0.980140209197998
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46600>, epoch_step = 1600, loss = 1.0245968103408813
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46700>, epoch_step = 1700, loss = 1.0359179973602295
# epoch = 24, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46800>, epoch_step = 1800, loss = 1.0328319072723389
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=46900>, epoch_step = 25, loss = 0.9989286661148071
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47000>, epoch_step = 125, loss = 1.0355780124664307
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47100>, epoch_step = 225, loss = 1.0032405853271484
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47200>, epoch_step = 325, loss = 0.9684301018714905
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47300>, epoch_step = 425, loss = 1.0137381553649902
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47400>, epoch_step = 525, loss = 0.9494338631629944
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47500>, epoch_step = 625, loss = 0.9849546551704407
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47600>, epoch_step = 725, loss = 0.9780104160308838
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47700>, epoch_step = 825, loss = 0.9393458366394043
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47800>, epoch_step = 925, loss = 1.058821678161621
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=47900>, epoch_step = 1025, loss = 0.9950233697891235
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48000>, epoch_step = 1125, loss = 1.0235124826431274
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48100>, epoch_step = 1225, loss = 1.0092875957489014
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48200>, epoch_step = 1325, loss = 1.0669481754302979
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48300>, epoch_step = 1425, loss = 1.0123374462127686
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48400>, epoch_step = 1525, loss = 0.9144829511642456
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48500>, epoch_step = 1625, loss = 0.9970909357070923
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48600>, epoch_step = 1725, loss = 1.0216177701950073
# epoch = 25, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48700>, epoch_step = 1825, loss = 0.9322916269302368
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48800>, epoch_step = 50, loss = 0.9342219829559326
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=48900>, epoch_step = 150, loss = 1.0310508012771606
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49000>, epoch_step = 250, loss = 1.002789855003357
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49100>, epoch_step = 350, loss = 0.9739189147949219
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49200>, epoch_step = 450, loss = 0.9957588911056519
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49300>, epoch_step = 550, loss = 1.0622797012329102
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49400>, epoch_step = 650, loss = 0.9384092688560486
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49500>, epoch_step = 750, loss = 1.036865472793579
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49600>, epoch_step = 850, loss = 0.9797659516334534
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49700>, epoch_step = 950, loss = 1.0751783847808838
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49800>, epoch_step = 1050, loss = 0.9881516098976135
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=49900>, epoch_step = 1150, loss = 0.9580735564231873
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50000>, epoch_step = 1250, loss = 1.0344648361206055
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50100>, epoch_step = 1350, loss = 0.9846629500389099
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50200>, epoch_step = 1450, loss = 0.9839527606964111
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50300>, epoch_step = 1550, loss = 1.035298466682434
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50400>, epoch_step = 1650, loss = 0.9773184061050415
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50500>, epoch_step = 1750, loss = 0.9784187078475952
# epoch = 26, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50600>, epoch_step = 1850, loss = 0.9688599109649658
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50700>, epoch_step = 75, loss = 0.9540525674819946
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50800>, epoch_step = 175, loss = 1.0414961576461792
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=50900>, epoch_step = 275, loss = 0.9768092036247253
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51000>, epoch_step = 375, loss = 0.9762449264526367
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51100>, epoch_step = 475, loss = 0.9479161500930786
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51200>, epoch_step = 575, loss = 0.9566198587417603
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51300>, epoch_step = 675, loss = 0.9424898624420166
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51400>, epoch_step = 775, loss = 1.0152955055236816
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51500>, epoch_step = 875, loss = 1.0293829441070557
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51600>, epoch_step = 975, loss = 1.0302246809005737
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51700>, epoch_step = 1075, loss = 0.9591130614280701
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51800>, epoch_step = 1175, loss = 0.9662739634513855
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=51900>, epoch_step = 1275, loss = 0.9661681652069092
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52000>, epoch_step = 1375, loss = 1.0366917848587036
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52100>, epoch_step = 1475, loss = 0.9583766460418701
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52200>, epoch_step = 1575, loss = 0.9976871013641357
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52300>, epoch_step = 1675, loss = 1.0721796751022339
# epoch = 27, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52400>, epoch_step = 1775, loss = 1.0643030405044556
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52500>, epoch_step = 0, loss = 0.9635158777236938
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52600>, epoch_step = 100, loss = 0.9430534839630127
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52700>, epoch_step = 200, loss = 0.9472392797470093
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52800>, epoch_step = 300, loss = 1.0027329921722412
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=52900>, epoch_step = 400, loss = 1.0170490741729736
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53000>, epoch_step = 500, loss = 1.0362998247146606
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53100>, epoch_step = 600, loss = 0.9961215257644653
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53200>, epoch_step = 700, loss = 0.9952970743179321
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53300>, epoch_step = 800, loss = 0.974694013595581
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53400>, epoch_step = 900, loss = 0.969074547290802
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53500>, epoch_step = 1000, loss = 1.0145690441131592
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53600>, epoch_step = 1100, loss = 1.1063756942749023
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53700>, epoch_step = 1200, loss = 0.9501624703407288
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53800>, epoch_step = 1300, loss = 1.0329457521438599
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=53900>, epoch_step = 1400, loss = 1.002934455871582
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54000>, epoch_step = 1500, loss = 0.9017992615699768
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54100>, epoch_step = 1600, loss = 1.034935474395752
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54200>, epoch_step = 1700, loss = 0.968313455581665
# epoch = 28, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54300>, epoch_step = 1800, loss = 0.9619886875152588
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54400>, epoch_step = 25, loss = 1.0116775035858154
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54500>, epoch_step = 125, loss = 0.9879825115203857
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54600>, epoch_step = 225, loss = 0.9613891839981079
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54700>, epoch_step = 325, loss = 0.9913378953933716
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54800>, epoch_step = 425, loss = 1.0436813831329346
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=54900>, epoch_step = 525, loss = 0.975612998008728
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55000>, epoch_step = 625, loss = 0.9678129553794861
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55100>, epoch_step = 725, loss = 1.009332299232483
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55200>, epoch_step = 825, loss = 1.098375678062439
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55300>, epoch_step = 925, loss = 0.9842625856399536
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55400>, epoch_step = 1025, loss = 0.9951159358024597
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55500>, epoch_step = 1125, loss = 1.0224827527999878
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55600>, epoch_step = 1225, loss = 1.012058973312378
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55700>, epoch_step = 1325, loss = 0.9932818412780762
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55800>, epoch_step = 1425, loss = 1.0238255262374878
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=55900>, epoch_step = 1525, loss = 1.0941202640533447
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=56000>, epoch_step = 1625, loss = 1.0010915994644165
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=56100>, epoch_step = 1725, loss = 0.9609178304672241
# epoch = 29, global_step = <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=56200>, epoch_step = 1825, loss = 0.969095766544342
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731075031/assets

# %%
# !gsutil ls ${OUTPUT_DIR}
# Out:
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/summaries/

# %%
# !gsutil ls ${OUTPUT_DIR}/checkpoints
# Out:
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/checkpoint
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-0.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-10000.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-10000.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-10000.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-20000.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-20000.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-20000.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-30000.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-30000.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-30000.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-40000.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-40000.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-40000.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-50000.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-50000.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-50000.index
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-56250.data-00000-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-56250.data-00001-of-00002
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/checkpoints/ckpt-56250.index

# %%
# !gsutil ls ${OUTPUT_DIR}/summaries
# Out:
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/summaries/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/summaries/events.out.tfevents.1596180958.tensorflow-2-2-20200707-090436.17784.1827.v2

# %% [markdown]
# ## Prediction

# %%
# !gsutil ls ${OUTPUT_DIR}/export
# Out:
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/
# gs://machine-learning-1234-bucket/gan/dcgan/tf2/trained_model/export/20200731075031/

# %%
loaded = tf.saved_model.load(
    export_dir=os.path.join(
        arguments["output_dir"], "export", "20200731075031"
    )
)
print(list(loaded.signatures.keys()))
# Out:
# ['serving_default']

# %%
infer = loaded.signatures["serving_default"]
print(infer.structured_outputs)
# Out:
# {'generator_resize_fake_images': TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='generator_resize_fake_images')}

# %%
Z = tf.random.normal(shape=(10, 512))
predictions = infer(Z)

# %%
predictions.keys()
# Out:
# dict_keys(['generator_resize_fake_images'])

# %% [markdown]
# Convert image back to the original scale.

# %%
generated_images = np.clip(
    a=tf.cast(
        x=((predictions["generator_resize_fake_images"] + 1.0) * (255. / 2)),
        dtype=tf.int32
    ),
    a_min=0,
    a_max=255
)

# %%
print(generated_images.shape)
# Out:
# (10, 28, 28, 1)

# %%
def plot_images(images):
    """Plots images.

    Args:
        images: np.array, array of images of
            [num_images, image_size, image_size, num_channels].
    """
    num_images = len(images)

    plt.figure(figsize=(20, 20))
    for i in range(num_images):
        image = images[i]
        plt.subplot(1, num_images, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(
            tf.reshape(image, image.shape[:-1]),
            cmap="gray_r"
        )
    plt.show()

# %%
plot_images(generated_images)
